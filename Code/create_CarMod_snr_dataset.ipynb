# %% [markdown]
# # Code to create HDF5 datasets (at different SNRs) for vIHC-based 2D-Carrier/Modulation power data
# Notebook outline:
# 1. Load required packages
# 2. Define a function to create dataset for a single SNR
# 3. Loop through SNRs to create different hdf5 files

# %% [markdown]
# ## 1. Load required packages

# %%
import os 
import numpy as np 
import h5py
import scipy.io
import matlab_helpers as mh 
from keras.utils import to_categorical

# %% [markdown]
# ## 2. Define a function to create dataset for a single SNR
# Steps are
# * Read SNR
# * Define the right input and output directories/files
# * Read all data
# * Save HDF5 (X, Y, and filenames)

# %%
def save_snr_data(snr_value):
    root_in_dir= '../Datasets/CarModPow/'
    root_out_dir= '../Datasets/CarModPow/PyData/'
    if not os.path.exists(root_out_dir):
        os.makedirs(root_out_dir)
    
    post_search_str = '/CarMod_'
    if np.isinf(snr_value):
        pre_search_str = 'clean/'
        root_matdata_dir = root_in_dir + 'level65_dBspl_clean/'
        out_allfiles_txt_fname = root_out_dir + 'CarMod_data_list_clean.txt'
        out_CarMod_data_file = root_out_dir + 'CarMod_data_clean.h5'
    else:
        pre_search_str = '_white/'
        root_matdata_dir = root_in_dir + 'level65_dBspl_SNR' + snr_value.astype('int').astype('str') + '_white/'
        out_allfiles_txt_fname = root_out_dir + 'CarMod_data_list_SNR' + snr_value.astype('int').astype('str') + '.txt'
        out_CarMod_data_file = root_out_dir + 'CarMod_data_SNR' + snr_value.astype('int').astype('str') + '.h5'

    if (not os.path.exists(out_CarMod_data_file)):
        if os.path.exists(root_matdata_dir):
            print(f"Working on: {root_matdata_dir}")
        else:
            print(f"Nooooooooo: {root_matdata_dir}")

        valid_datadirs = ['Chut', 'HighWhistle', 'Rumble', 'Tchatter', 'Wheek', 'Whine']
        calls2use = ['Chut', 'Rumble', 'Wheek', 'Whine']

        all_files_nameonly= []
        CarMod_data_list= []

        for cur_call_dir in valid_datadirs:
            cur_call_path = root_matdata_dir + cur_call_dir + '/' 
            # print(cur_call_path)
            cur_dir_files = [f for f in os.listdir(cur_call_path) if os.path.isfile(os.path.join(cur_call_path, f))]
            all_files_nameonly = all_files_nameonly + cur_dir_files
            CarMod_data_list = CarMod_data_list + [cur_call_path + f for f in cur_dir_files]

        print(f"--> all_files_nameonly: len lines= {len(all_files_nameonly)}, first line = {all_files_nameonly[0]}")
        print(f"--> CarMod_data_list: len lines= {len(CarMod_data_list)}, first line = {CarMod_data_list[0]}")

        with open(out_allfiles_txt_fname, 'w') as f:
            for line in CarMod_data_list:
                f.write(f"{line}\n")


        data_label_name = [item[item.rfind(pre_search_str)+len(pre_search_str):item.rfind(post_search_str)] for item in CarMod_data_list]
        data_label_y = len(calls2use)*np.ones((len(data_label_name),1))
        print(f"len: CarMod_data_list = {len(CarMod_data_list)} || data_label_name = {len(data_label_name)}")        
        print(f"first ex: CarMod_data_list = {CarMod_data_list[0]} || data_label_name = {data_label_name[0]}")
        # data_label_y= to_categorical(data_label_y)
        print(data_label_y.shape)
        

        for ind, cur_call in zip(np.arange(len(data_label_name)),data_label_name):
            # print(f"ind={ind}|cur_call={cur_call}|call2use={calls2use}")
            if cur_call in calls2use: 
                data_label_y[ind,0] = calls2use.index(cur_call)
        data_label_y = np.array(data_label_y).astype(int)                
        unq_vals, unq_counts = np.unique(data_label_y, return_counts=True)
        print(dict(zip(unq_vals,unq_counts)))

        print(len(data_label_y))

        chunk_size = 5 
        n_chunks = np.ceil(len(data_label_y)/chunk_size).astype('int')
        print(f"n_chunks={n_chunks}")
        hf = h5py.File(out_CarMod_data_file, "a")
        print("Saving file" + out_CarMod_data_file)
        
        for chunkVar in range(n_chunks):
            cur_chunk_CarMod_x = []
            cur_chunk_label_y = []
            cur_chunk_fName = []
            for inds_in_chunk in range(chunk_size):
                file_ind = chunkVar*chunk_size+inds_in_chunk
                
                fName = CarMod_data_list[file_ind]
                new_data = mh.loadmat(fName)
                cur_chunk_CarMod_x.append(np.array(new_data["CarMod_power"]["CarMod_power"]))
                cur_chunk_label_y.append(data_label_y[file_ind])
                cur_chunk_fName.append(fName)
                # print(f"chunkVar={chunkVar}: inds_in_chunk={file_ind}")
            
            cur_chunk_CarMod_x= np.array(cur_chunk_CarMod_x)
            cur_chunk_label_y = np.array(cur_chunk_label_y).astype(int)                        
            cur_chunk_fName = np.array(cur_chunk_fName)
            # print(f"type={type(cur_chunk_label_y)}")
            print(f"chunkVar={chunkVar} data_CarMod_x.shape={cur_chunk_CarMod_x.shape} | data_label_y.shape={cur_chunk_label_y.shape}, cur_chunk_fName={cur_chunk_fName.shape}")

            if chunkVar == 0:
                # Create the dataset at first
                hf.create_dataset('data_CarMod_x', data=cur_chunk_CarMod_x, compression="gzip", chunks=True, maxshape=(None,67,9))
                hf.create_dataset('data_label_y', data=cur_chunk_label_y, compression="gzip", chunks=True, maxshape=(None,1)) 
                # hf.create_dataset('data_filename', data=cur_chunk_fName, compression="gzip", maxshape=(None,)) 
            else:
                # Append new data to it
                hf['data_CarMod_x'].resize((hf['data_CarMod_x'].shape[0] + chunk_size), axis=0)
                hf['data_CarMod_x'][-chunk_size:] = cur_chunk_CarMod_x

                hf['data_label_y'].resize((hf['data_label_y'].shape[0] + chunk_size), axis=0)
                hf['data_label_y'][-chunk_size:] = cur_chunk_label_y

                # hf['data_filename'].resize((hf['data_filename'].shape[0] + chunk_size), axis=0)
                # hf['data_filename'][-chunk_size:] = cur_chunk_fName

        hf.close()

    else: 
        print("File (" + out_CarMod_data_file + ") already exists")

# all_snrs= np.arange(-20.0, 11, 5)
# all_snrs= np.append(all_snrs, np.inf)
# for snr_val in all_snrs:
#     save_snr_data(snr_val)
# Out:
# Working on: D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-20_white/
# --> all_files_nameonly: len lines= 1605, first line = CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat
# --> CarMod_data_list: len lines= 1605, first line = D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-20_white/Chut/CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat
# len: CarMod_data_list = 1605 || data_label_name = 1605
# first ex: CarMod_data_list = D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-20_white/Chut/CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat || data_label_name = Chut
# (1605, 1)
# {0: 432, 1: 253, 2: 372, 3: 457, 4: 91}
# 1605
# n_chunks=321
# Saving fileD:/Dropbox/Python/MLmodels/Datasets/CarModPow/PyData/CarMod_data_SNR-20.h5
# chunkVar=0 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=1 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=2 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=3 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=4 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=5 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=6 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=7 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=8 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=9 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=10 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=11 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=12 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=13 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=14 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=15 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=16 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=17 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=18 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=19 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=20 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=21 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=22 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=23 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=24 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=25 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=26 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=27 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=28 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=29 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=30 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=31 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=32 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=33 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=34 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=35 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=36 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=37 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=38 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=39 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=40 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=41 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=42 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=43 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=44 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=45 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=46 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=47 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=48 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=49 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=50 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=51 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=52 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=53 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=54 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=55 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=56 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=57 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=58 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=59 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=60 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=61 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=62 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=63 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=64 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=65 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=66 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=67 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=68 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=69 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=70 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=71 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=72 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=73 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=74 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=75 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=76 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=77 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=78 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=79 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=80 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=81 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=82 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=83 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=84 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=85 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=86 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=87 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=88 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=89 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=90 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=91 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=92 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=93 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=94 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=95 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=96 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=97 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=98 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=99 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=100 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=101 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=102 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=103 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=104 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=105 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=106 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=107 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=108 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=109 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=110 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=111 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=112 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=113 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=114 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=115 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=116 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=117 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=118 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=119 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=120 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=121 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=122 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=123 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=124 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=125 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=126 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=127 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=128 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=129 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=130 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=131 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=132 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=133 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=134 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=135 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=136 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=137 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=138 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=139 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=140 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=141 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=142 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=143 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=144 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=145 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=146 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=147 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=148 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=149 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=150 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=151 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=152 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=153 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=154 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=155 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=156 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=157 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=158 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=159 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=160 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=161 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=162 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=163 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=164 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=165 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=166 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=167 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=168 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=169 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=170 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=171 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=172 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=173 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=174 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=175 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=176 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=177 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=178 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=179 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=180 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=181 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=182 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=183 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=184 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=185 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=186 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=187 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=188 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=189 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=190 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=191 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=192 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=193 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=194 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=195 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=196 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=197 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=198 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=199 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=200 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=201 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=202 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=203 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=204 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=205 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=206 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=207 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=208 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=209 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=210 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=211 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=212 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=213 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=214 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=215 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=216 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=217 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=218 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=219 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=220 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=221 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=222 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=223 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=224 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=225 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=226 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=227 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=228 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=229 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=230 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=231 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=232 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=233 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=234 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=235 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=236 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=237 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=238 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=239 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=240 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=241 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=242 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=243 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=244 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=245 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=246 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=247 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=248 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=249 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=250 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=251 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=252 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=253 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=254 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=255 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=256 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=257 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=258 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=259 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=260 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=261 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=262 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=263 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=264 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=265 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=266 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=267 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=268 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=269 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=270 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=271 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=272 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=273 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=274 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=275 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=276 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=277 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=278 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=279 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=280 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=281 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=282 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=283 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=284 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=285 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=286 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=287 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=288 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=289 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=290 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=291 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=292 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=293 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=294 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=295 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=296 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=297 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=298 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=299 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=300 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=301 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=302 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=303 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=304 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=305 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=306 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=307 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=308 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=309 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=310 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=311 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=312 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=313 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=314 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=315 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=316 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=317 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=318 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=319 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar=320 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# Working on: D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-15_white/
# --> all_files_nameonly: len lines= 1605, first line = CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat
# --> CarMod_data_list: len lines= 1605, first line = D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-15_white/Chut/CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat
# len: CarMod_data_list = 1605 || data_label_name = 1605
# first ex: CarMod_data_list = D:/Dropbox/Python/MLmodels/Datasets/CarModPow/level65_dBspl_SNR-15_white/Chut/CarMod_psd_Chut_2_Feb_07_2022_51861688_ms_101198_101787.mat || data_label_name = Chut
# (1605, 1)
# {0: 432, 1: 253, 2: 372, 3: 457, 4: 91}
# 1605
# n_chunks=321
# Saving fileD:/Dropbox/Python/MLmodels/Datasets/CarModPow/PyData/CarMod_data_SNR-15.h5
# chunkVar=0 data_CarMod_x.shape=(5, 67, 9) | data_label_y.shape=(5, 1), cur_chunk_fName=(5,)
# chunkVar