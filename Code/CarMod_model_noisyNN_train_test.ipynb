# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import h5py 
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import random
import copy
from scipy.io import savemat

# %% [markdown]
# ## Load datasets
# 1. Load noisy datasets to train the mimmax_scaler
# 2. Load clean data to train MLPclean
# 3. Load noisy data to train MLPnoisy

# %%
all_snrs= np.arange(-20.0, 11, 5)
all_snrs= np.append(all_snrs, np.inf)
snr_training_weights= np.flip(len(all_snrs)-np.arange(len(all_snrs)))/len(all_snrs)
print(snr_training_weights)

root_data_dir= 'D:/Dropbox/Python/MLmodels/Datasets/CarModPow/PyData/'

# Load clean data 
train_test_dataset = h5py.File(root_data_dir + 'CarMod_data_clean.h5', "r")
data_x_clean_orig = np.array(train_test_dataset["data_CarMod_x"][:]) # your train set features
data_y_clean_orig = np.ravel(np.array(train_test_dataset["data_label_y"][:])) # your train set labels

print(f"pre-shape:data_x_clean_orig={data_x_clean_orig.shape}, data_y_clean_orig={data_y_clean_orig.shape}")
data_x_clean_orig = np.reshape(data_x_clean_orig,(data_x_clean_orig.shape[0],data_x_clean_orig.shape[1]*data_x_clean_orig.shape[2]))
print(f"post-shape:data_x_clean_orig={data_x_clean_orig.shape}, data_y_clean_orig={data_y_clean_orig.shape}")
# data_clean_fnames = np.ravel(np.array(train_test_dataset["data_filename"][:])) # your train set labels

train_inds, test_inds = train_test_split(np.arange(data_x_clean_orig.shape[0]), test_size=0.25, random_state=1)

all_train_x_orig = data_x_clean_orig[train_inds]
all_train_y_orig = data_y_clean_orig[train_inds]

# Load all SNR data 
for snr_value,snr_weight in zip(all_snrs[0:-1], snr_training_weights[0:-1]):
    print(f"SNR={snr_value} dB and weight = {snr_weight}")
    out_CarMod_data_file = root_data_dir + 'CarMod_data_SNR' + snr_value.astype('int').astype('str') + '.h5'    
    cur_dataset = h5py.File(out_CarMod_data_file, "r")
        
    cur_x = np.array(cur_dataset["data_CarMod_x"][:])
    cur_x = np.reshape(cur_x,(cur_x.shape[0],cur_x.shape[1]*cur_x.shape[2]))
    cur_y = np.ravel(np.array(cur_dataset["data_label_y"][:]))
    
    sample_inds_training, _= train_test_split(np.arange(len(train_inds)), test_size= 1-snr_weight, random_state=1)

    all_train_x_orig = np.concatenate((all_train_x_orig, cur_x[train_inds[sample_inds_training]]))
    all_train_y_orig = np.concatenate((all_train_y_orig, cur_y[train_inds[sample_inds_training]]))
    print(f"shape:cur={cur_x.shape},cur_subsamp={len(sample_inds_training)}, full={len(train_inds)}, all_train_x_orig={all_train_x_orig.shape},type={type(cur_x)}")

minmax_scaler = MinMaxScaler()
minmax_scaler.fit(all_train_x_orig)

train_set_x_norm = minmax_scaler.transform(data_x_clean_orig)
all_train_x_norm = minmax_scaler.transform(all_train_x_orig)

X_train_clean, X_test_clean, y_train_clean, y_test_clean, train_inds, test_inds = train_test_split \
    (train_set_x_norm, data_y_clean_orig, np.arange(train_set_x_norm.shape[0]), test_size=0.25, random_state=1)
print(f"Type: X_train_clean={type(X_train_clean)}, y_train_clean={type(y_train_clean)}")
print(f"Shapes: X_train_clean={X_train_clean.shape}, y_train_clean={y_train_clean.shape}, X_test_clean={X_test_clean.shape}, y_test_clean={y_test_clean.shape}")

unq_vals, unq_counts = np.unique(y_train_clean, return_counts=True)
print(dict(zip(unq_vals,unq_counts)))
# Out:
# [0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# pre-shape:data_x_clean_orig=(1605, 67, 9), data_y_clean_orig=(1605,)
# post-shape:data_x_clean_orig=(1605, 603), data_y_clean_orig=(1605,)
# SNR=-20.0 dB and weight = 0.125
# shape:cur=(1605, 603),cur_subsamp=150, full=1203, all_train_x_orig=(1353, 603),type=<class 'numpy.ndarray'>
# SNR=-15.0 dB and weight = 0.25
# shape:cur=(1605, 603),cur_subsamp=300, full=1203, all_train_x_orig=(1653, 603),type=<class 'numpy.ndarray'>
# SNR=-10.0 dB and weight = 0.375
# shape:cur=(1605, 603),cur_subsamp=451, full=1203, all_train_x_orig=(2104, 603),type=<class 'numpy.ndarray'>
# SNR=-5.0 dB and weight = 0.5
# shape:cur=(1605, 603),cur_subsamp=601, full=1203, all_train_x_orig=(2705, 603),type=<class 'numpy.ndarray'>
# SNR=0.0 dB and weight = 0.625
# shape:cur=(1605, 603),cur_subsamp=751, full=1203, all_train_x_orig=(3456, 603),type=<class 'numpy.ndarray'>
# SNR=5.0 dB and weight = 0.75
# shape:cur=(1605, 603),cur_subsamp=902, full=1203, all_train_x_orig=(4358, 603),type=<class 'numpy.ndarray'>
# SNR=10.0 dB and weight = 0.875
# shape:cur=(1605, 603),cur_subsamp=1052, full=1203, all_train_x_orig=(5410, 603),type=<class 'numpy.ndarray'>
# Type: X_train_clean=<class 'numpy.ndarray'>, y_train_clean=<class 'numpy.ndarray'>
# Shapes: X_train_clean=(1203, 603), y_train_clean=(1203,), X_test_clean=(402, 603), y_test_clean=(402,)
# {0: 327, 1: 191, 2: 285, 3: 328, 4: 72}

# %% [markdown]
# ## Model #1: An SVM model (rbf kernels seem to work the best)

# %%
svm_model = svm.SVC(kernel='rbf').fit(X_train_clean, y_train_clean)
y_train_pred = svm_model.predict(X_train_clean)
y_test_pred = svm_model.predict(X_test_clean)

print(f"Unique values in y_test_pred={np.unique(y_test_pred)}")
print(f"Unique values in y_train_clean={np.unique(y_train_clean)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_clean==y_train_pred)/len(y_train_pred)}\n Testing accuracy={np.sum(y_test_clean==y_test_pred)/len(y_test_pred)}\n")
# Out:
# Unique values in y_test_pred=[0 1 2 3 4]
# Unique values in y_train_clean=[0 1 2 3 4]
# Training accuracy=0.9875311720698254
#  Testing accuracy=0.9701492537313433

# %% [markdown]
# ## Model #2. Train an MLP

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPclean = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPclean.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy'],
)

# Fit the model 
MLPclean.fit(
    X_train_clean,y_train_clean,
    epochs=200
)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 4s 3ms/step - loss: 0.4943 - accuracy: 0.8421
# Epoch 2/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9576
# Epoch 3/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9626
# Epoch 4/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.9751
# Epoch 5/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9784
# Epoch 6/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0715 - accuracy: 0.9809
# Epoch 7/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9809
# Epoch 8/200
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9767
# Epoch 9/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9784
# Epoch 10/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9900
# Epoch 11/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9867
# Epoch 12/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9767
# Epoch 13/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9875
# Epoch 14/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9925
# Epoch 15/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9967
# Epoch 16/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9909
# Epoch 17/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9917
# Epoch 18/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9950
# Epoch 19/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9950
# Epoch 20/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9942
# Epoch 21/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9958
# Epoch 22/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9958
# Epoch 23/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9967
# Epoch 24/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9958
# Epoch 25/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9967
# Epoch 26/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9967
# Epoch 27/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9967
# Epoch 28/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9967
# Epoch 29/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9975
# Epoch 30/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9983
# Epoch 31/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9975
# Epoch 32/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9983
# Epoch 33/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9950
# Epoch 34/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.9967
# Epoch 35/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9942
# Epoch 36/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9950
# Epoch 37/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9983
# Epoch 38/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9917
# Epoch 39/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9933
# Epoch 40/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9958
# Epoch 41/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9950
# Epoch 42/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 0.9992
# Epoch 43/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9992
# Epoch 44/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9992
# Epoch 45/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 46/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 0.9992
# Epoch 47/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9992
# Epoch 48/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 0.9992
# Epoch 49/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9967
# Epoch 50/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 51/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 52/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 53/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.9983
# Epoch 54/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 55/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9992
# Epoch 56/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 57/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 58/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 59/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 60/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9983
# Epoch 61/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 62/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 63/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9992
# Epoch 64/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 65/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 66/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 67/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 68/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 69/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 70/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.7437e-04 - accuracy: 1.0000
# Epoch 71/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 72/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.5686e-04 - accuracy: 1.0000
# Epoch 73/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.4079e-04 - accuracy: 1.0000
# Epoch 74/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.6709e-04 - accuracy: 1.0000
# Epoch 75/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.0478e-04 - accuracy: 1.0000
# Epoch 76/200
# 38/38 [==============================] - 0s 3ms/step - loss: 7.9222e-04 - accuracy: 1.0000
# Epoch 77/200
# 38/38 [==============================] - 0s 3ms/step - loss: 8.1407e-04 - accuracy: 1.0000
# Epoch 78/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 79/200
# 38/38 [==============================] - 0s 3ms/step - loss: 6.4899e-04 - accuracy: 1.0000
# Epoch 80/200
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1321e-04 - accuracy: 1.0000
# Epoch 81/200
# 38/38 [==============================] - 0s 3ms/step - loss: 6.3348e-04 - accuracy: 1.0000
# Epoch 82/200
# 38/38 [==============================] - 0s 3ms/step - loss: 4.5240e-04 - accuracy: 1.0000
# Epoch 83/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2506e-04 - accuracy: 1.0000
# Epoch 84/200
# 38/38 [==============================] - 0s 3ms/step - loss: 5.0745e-04 - accuracy: 1.0000
# Epoch 85/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.0174e-04 - accuracy: 1.0000
# Epoch 86/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.2698e-04 - accuracy: 1.0000
# Epoch 87/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9659e-04 - accuracy: 1.0000
# Epoch 88/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9314e-04 - accuracy: 1.0000
# Epoch 89/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.6437e-04 - accuracy: 1.0000
# Epoch 90/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.5818e-04 - accuracy: 1.0000
# Epoch 91/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.5396e-04 - accuracy: 1.0000
# Epoch 92/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9421e-04 - accuracy: 1.0000
# Epoch 93/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.4582e-04 - accuracy: 1.0000
# Epoch 94/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2274e-04 - accuracy: 1.0000
# Epoch 95/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.5530e-04 - accuracy: 1.0000
# Epoch 96/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2382e-04 - accuracy: 1.0000
# Epoch 97/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2580e-04 - accuracy: 1.0000
# Epoch 98/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.9718e-04 - accuracy: 1.0000
# Epoch 99/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8647e-04 - accuracy: 1.0000
# Epoch 100/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5716e-04 - accuracy: 1.0000
# Epoch 101/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.7631e-04 - accuracy: 1.0000
# Epoch 102/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4797e-04 - accuracy: 1.0000
# Epoch 103/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5311e-04 - accuracy: 1.0000
# Epoch 104/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4835e-04 - accuracy: 1.0000
# Epoch 105/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2679e-04 - accuracy: 1.0000
# Epoch 106/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2695e-04 - accuracy: 1.0000
# Epoch 107/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.1865e-04 - accuracy: 1.0000
# Epoch 108/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0687e-04 - accuracy: 1.0000
# Epoch 109/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.1683e-04 - accuracy: 1.0000
# Epoch 110/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0975e-04 - accuracy: 1.0000
# Epoch 111/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.3349e-04 - accuracy: 1.0000
# Epoch 112/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0500e-04 - accuracy: 1.0000
# Epoch 113/200
# 38/38 [==============================] - 0s 3ms/step - loss: 1.7905e-04 - accuracy: 1.0000
# Epoch 114/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6619e-04 - accuracy: 1.0000
# Epoch 115/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8367e-04 - accuracy: 1.0000
# Epoch 116/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8189e-04 - accuracy: 1.0000
# Epoch 117/200
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6471e-04 - accuracy: 1.0000
# Epoch 118/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5843e-04 - accuracy: 1.0000
# Epoch 119/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5170e-04 - accuracy: 1.0000
# Epoch 120/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5057e-04 - accuracy: 1.0000
# Epoch 121/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3975e-04 - accuracy: 1.0000
# Epoch 122/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5309e-04 - accuracy: 1.0000
# Epoch 123/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3481e-04 - accuracy: 1.0000
# Epoch 124/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3352e-04 - accuracy: 1.0000
# Epoch 125/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3840e-04 - accuracy: 1.0000
# Epoch 126/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2435e-04 - accuracy: 1.0000
# Epoch 127/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2884e-04 - accuracy: 1.0000
# Epoch 128/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2851e-04 - accuracy: 1.0000
# Epoch 129/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1724e-04 - accuracy: 1.0000
# Epoch 130/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1915e-04 - accuracy: 1.0000
# Epoch 131/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1298e-04 - accuracy: 1.0000
# Epoch 132/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0943e-04 - accuracy: 1.0000
# Epoch 133/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0968e-04 - accuracy: 1.0000
# Epoch 134/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.9352e-05 - accuracy: 1.0000
# Epoch 135/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0809e-04 - accuracy: 1.0000
# Epoch 136/200
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0083e-04 - accuracy: 1.0000
# Epoch 137/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.0768e-05 - accuracy: 1.0000
# Epoch 138/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.3793e-05 - accuracy: 1.0000
# Epoch 139/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.8410e-05 - accuracy: 1.0000
# Epoch 140/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.1710e-05 - accuracy: 1.0000
# Epoch 141/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.6439e-05 - accuracy: 1.0000
# Epoch 142/200
# 38/38 [==============================] - 0s 2ms/step - loss: 9.6107e-05 - accuracy: 1.0000
# Epoch 143/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.7259e-05 - accuracy: 1.0000
# Epoch 144/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.5319e-05 - accuracy: 1.0000
# Epoch 145/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.2466e-05 - accuracy: 1.0000
# Epoch 146/200
# 38/38 [==============================] - 0s 2ms/step - loss: 8.9619e-05 - accuracy: 1.0000
# Epoch 147/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.1263e-05 - accuracy: 1.0000
# Epoch 148/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.7888e-05 - accuracy: 1.0000
# Epoch 149/200
# 38/38 [==============================] - 0s 3ms/step - loss: 7.5987e-05 - accuracy: 1.0000
# Epoch 150/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.2734e-05 - accuracy: 1.0000
# Epoch 151/200
# 38/38 [==============================] - 0s 2ms/step - loss: 7.3662e-05 - accuracy: 1.0000
# Epoch 152/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.7035e-05 - accuracy: 1.0000
# Epoch 153/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.1933e-05 - accuracy: 1.0000
# Epoch 154/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.6119e-05 - accuracy: 1.0000
# Epoch 155/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.5271e-05 - accuracy: 1.0000
# Epoch 156/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6653e-05 - accuracy: 1.0000
# Epoch 157/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.6021e-05 - accuracy: 1.0000
# Epoch 158/200
# 38/38 [==============================] - 0s 2ms/step - loss: 6.3572e-05 - accuracy: 1.0000
# Epoch 159/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8000e-05 - accuracy: 1.0000
# Epoch 160/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6625e-05 - accuracy: 1.0000
# Epoch 161/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5400e-05 - accuracy: 1.0000
# Epoch 162/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6243e-05 - accuracy: 1.0000
# Epoch 163/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3061e-05 - accuracy: 1.0000
# Epoch 164/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.0141e-05 - accuracy: 1.0000
# Epoch 165/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.9762e-05 - accuracy: 1.0000
# Epoch 166/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.9072e-05 - accuracy: 1.0000
# Epoch 167/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.9203e-05 - accuracy: 1.0000
# Epoch 168/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.4837e-05 - accuracy: 1.0000
# Epoch 169/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.5389e-05 - accuracy: 1.0000
# Epoch 170/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.5717e-05 - accuracy: 1.0000
# Epoch 171/200
# 38/38 [==============================] - 0s 3ms/step - loss: 4.1610e-05 - accuracy: 1.0000
# Epoch 172/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.6531e-05 - accuracy: 1.0000
# Epoch 173/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.7379e-05 - accuracy: 1.0000
# Epoch 174/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.3047e-05 - accuracy: 1.0000
# Epoch 175/200
# 38/38 [==============================] - 0s 2ms/step - loss: 4.0486e-05 - accuracy: 1.0000
# Epoch 176/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.8424e-05 - accuracy: 1.0000
# Epoch 177/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9021e-05 - accuracy: 1.0000
# Epoch 178/200
# 38/38 [==============================] - 0s 3ms/step - loss: 3.8110e-05 - accuracy: 1.0000
# Epoch 179/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.7163e-05 - accuracy: 1.0000
# Epoch 180/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.7511e-05 - accuracy: 1.0000
# Epoch 181/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.5234e-05 - accuracy: 1.0000
# Epoch 182/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3010e-05 - accuracy: 1.0000
# Epoch 183/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3704e-05 - accuracy: 1.0000
# Epoch 184/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.1311e-05 - accuracy: 1.0000
# Epoch 185/200
# 38/38 [==============================] - 0s 3ms/step - loss: 3.1105e-05 - accuracy: 1.0000
# Epoch 186/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.1671e-05 - accuracy: 1.0000
# Epoch 187/200
# 38/38 [==============================] - 0s 2ms/step - loss: 3.7144e-05 - accuracy: 1.0000
# Epoch 188/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.9628e-05 - accuracy: 1.0000
# Epoch 189/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.9456e-05 - accuracy: 1.0000
# Epoch 190/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8785e-05 - accuracy: 1.0000
# Epoch 191/200
# 38/38 [==============================] - 0s 3ms/step - loss: 2.8906e-05 - accuracy: 1.0000
# Epoch 192/200
# 38/38 [==============================] - 0s 3ms/step - loss: 2.7969e-05 - accuracy: 1.0000
# Epoch 193/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8208e-05 - accuracy: 1.0000
# Epoch 194/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.6978e-05 - accuracy: 1.0000
# Epoch 195/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5738e-05 - accuracy: 1.0000
# Epoch 196/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4357e-05 - accuracy: 1.0000
# Epoch 197/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4093e-05 - accuracy: 1.0000
# Epoch 198/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2298e-05 - accuracy: 1.0000
# Epoch 199/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2593e-05 - accuracy: 1.0000
# Epoch 200/200
# 38/38 [==============================] - 0s 2ms/step - loss: 2.3605e-05 - accuracy: 1.0000

# %% [markdown]
# ## Test MLP accuracy for training and testing

# %%
y_train_pred_NN = np.argmax(MLPclean.predict(X_train_clean), axis=1)
y_test_pred_NN = np.argmax(MLPclean.predict(X_test_clean), axis=1)

print(f"Unique values in y_train_clean={np.unique(y_train_pred_NN)}")
print(f"Unique values in y_test_pred={np.unique(y_test_pred_NN)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred_NN, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_clean==y_train_pred_NN)/len(y_train_clean)}\n Testing accuracy={np.sum(y_test_clean==y_test_pred_NN)/len(y_test_clean)}\n")
# Out:
# 38/38 [==============================] - 0s 946us/step
# 13/13 [==============================] - 0s 1000us/step
# Unique values in y_train_clean=[0 1 2 3 4]
# Unique values in y_test_pred=[0 1 2 3 4]
# Training accuracy=1.0
#  Testing accuracy=0.9751243781094527

# %% [markdown]
# ## Model #3. MLP cleaned on noisy calls

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPnoisy = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPnoisy.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy'],
)

# Fit the model 
MLPnoisy.fit(
    all_train_x_norm, all_train_y_orig,
    epochs=50,
)
# Out:
# Epoch 1/50
# 170/170 [==============================] - 1s 3ms/step - loss: 0.5725 - accuracy: 0.8113
# Epoch 2/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8932
# Epoch 3/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9041
# Epoch 4/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.9002
# Epoch 5/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2352 - accuracy: 0.9194
# Epoch 6/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.9222
# Epoch 7/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9270
# Epoch 8/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 0.9336
# Epoch 9/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9229
# Epoch 10/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.9288
# Epoch 11/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.9405
# Epoch 12/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9277
# Epoch 13/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 0.9405
# Epoch 14/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9397
# Epoch 15/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1801 - accuracy: 0.9372
# Epoch 16/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9399
# Epoch 17/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.9420
# Epoch 18/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9468
# Epoch 19/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9486
# Epoch 20/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1607 - accuracy: 0.9457
# Epoch 21/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1402 - accuracy: 0.9510
# Epoch 22/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1528 - accuracy: 0.9484
# Epoch 23/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9460
# Epoch 24/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9477
# Epoch 25/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9519
# Epoch 26/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 0.9540
# Epoch 27/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9575
# Epoch 28/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9455
# Epoch 29/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.9359
# Epoch 30/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9560
# Epoch 31/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9540
# Epoch 32/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9569
# Epoch 33/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9529
# Epoch 34/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9549
# Epoch 35/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9573
# Epoch 36/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9386
# Epoch 37/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1138 - accuracy: 0.9606
# Epoch 38/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9638
# Epoch 39/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9494
# Epoch 40/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1498 - accuracy: 0.9516
# Epoch 41/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9645
# Epoch 42/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9647
# Epoch 43/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9647
# Epoch 44/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.9640
# Epoch 45/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9652
# Epoch 46/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9571
# Epoch 47/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9558
# Epoch 48/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9665
# Epoch 49/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9623
# Epoch 50/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9662

# %% [markdown]
# ## Test in different SNRs

# %%
def test_MLP_snr(MLPmodel, minmax_scaler, snr_value, test_inds_clean):
    root_out_dir= 'D:/Dropbox/Python/MLmodels/Datasets/CarModPow/PyData/'
    if np.isinf(snr_value):
        out_CarMod_data_file = root_data_dir + 'CarMod_data_clean.h5'
    else:
        out_CarMod_data_file = root_out_dir + 'CarMod_data_SNR' + snr_value.astype('int').astype('str') + '.h5'
    cur_snr_dataset = h5py.File(out_CarMod_data_file, "r")
    print(cur_snr_dataset)
    data_x_orig = np.array(cur_snr_dataset["data_CarMod_x"][:]) # your train set features
    data_x_orig= np.reshape(data_x_orig, (data_x_orig.shape[0],data_x_orig.shape[1]*data_x_orig.shape[2]))
    data_y_orig = np.ravel(np.array(cur_snr_dataset["data_label_y"][:])) # your train set labels
    # data_fnames = np.ravel(np.array(cur_snr_dataset["data_filename"][:])) # your train set labels
    data_x_norm = minmax_scaler.transform(data_x_orig)

    X_test = data_x_norm[test_inds]
    y_test = data_y_orig[test_inds]
    # fName_test= data_fnames[test_inds]
    
    # rand_int = random.randint(0, len(test_fnames_clean))
    # clean_name = test_fnames_clean[rand_int].decode("utf-8")
    # noisy_name= fName_test[rand_int].decode("utf-8")

    # print(f"fnumber={rand_int} |-| clean={clean_name}|noisy={noisy_name}")
    # clean_name= clean_name[clean_name.rfind('/')+1:-3]
    # noisy_name= noisy_name[noisy_name.rfind('/')+1:-3]
    # if clean_name!=noisy_name:
    #     print("Should be same")
    y_test_pred_NN = np.argmax(MLPmodel.predict(X_test), axis=1)
    accuracy = np.sum(y_test==y_test_pred_NN)/len(y_test_clean)
    print(f"[SNR={snr_value} dB] Accuracy={accuracy}\n")
    
    return accuracy


test_accuracy_cleanMLP = np.zeros(all_snrs.shape)
test_accuracy_noisyMLP = np.zeros(all_snrs.shape)
for snr_value,iter in zip(all_snrs,range(len(all_snrs))):
    test_accuracy_cleanMLP[iter]= test_MLP_snr(MLPclean, minmax_scaler, snr_value, test_inds)
    test_accuracy_noisyMLP[iter]= test_MLP_snr(MLPnoisy, minmax_scaler, snr_value, test_inds)
    # print(f"SNR={snr_value} dB | Accuracy={test_accuracy[iter]}")
# Out:
# <HDF5 file "CarMod_data_SNR-20.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-20.0 dB] Accuracy=0.05472636815920398
#
# <HDF5 file "CarMod_data_SNR-20.h5" (mode r)>
# 13/13 [==============================] - 0s 917us/step
# [SNR=-20.0 dB] Accuracy=0.373134328358209
#
# <HDF5 file "CarMod_data_SNR-15.h5" (mode r)>
# 13/13 [==============================] - 0s 1000us/step
# [SNR=-15.0 dB] Accuracy=0.07462686567164178
#
# <HDF5 file "CarMod_data_SNR-15.h5" (mode r)>
# 13/13 [==============================] - 0s 1000us/step
# [SNR=-15.0 dB] Accuracy=0.6169154228855721
#
# <HDF5 file "CarMod_data_SNR-10.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-10.0 dB] Accuracy=0.08706467661691543
#
# <HDF5 file "CarMod_data_SNR-10.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-10.0 dB] Accuracy=0.818407960199005
#
# <HDF5 file "CarMod_data_SNR-5.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-5.0 dB] Accuracy=0.1417910447761194
#
# <HDF5 file "CarMod_data_SNR-5.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-5.0 dB] Accuracy=0.9228855721393034
#
# <HDF5 file "CarMod_data_SNR0.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=0.0 dB] Accuracy=0.2935323383084577
#
# <HDF5 file "CarMod_data_SNR0.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=0.0 dB] Accuracy=0.9402985074626866
#
# <HDF5 file "CarMod_data_SNR5.h5" (mode r)>
# 13/13 [==============================] - 0s 1000us/step
# [SNR=5.0 dB] Accuracy=0.8084577114427861
#
# <HDF5 file "CarMod_data_SNR5.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=5.0 dB] Accuracy=0.9651741293532339
#
# <HDF5 file "CarMod_data_SNR10.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=10.0 dB] Accuracy=0.9502487562189055
#
# <HDF5 file "CarMod_data_SNR10.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=10.0 dB] Accuracy=0.9552238805970149
#
# <HDF5 file "CarMod_data_clean.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=inf dB] Accuracy=0.9751243781094527
#
# <HDF5 file "CarMod_data_clean.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=inf dB] Accuracy=0.9527363184079602

# %% [markdown]
# ## Plot results

# %%
plot_snr= copy.deepcopy(all_snrs)
plot_snr[np.isinf(plot_snr)] = 15
plt.plot(all_snrs, test_accuracy_cleanMLP, label="Clean-trained")
plt.plot(all_snrs, test_accuracy_noisyMLP, label="Noise-trained")
plt.xlabel("SNR (dB)")
plt.ylabel("Accuracy")
plt.title("Carrier (place) + modulation ")
plt.legend()

out_CarMod_classify_file = root_data_dir + 'CarMod_classify_out'
np.savez(out_CarMod_classify_file + '.npz', all_snrs=all_snrs, test_accuracy_noisyMLP=test_accuracy_noisyMLP, test_accuracy_cleanMLP=test_accuracy_cleanMLP)
mat_dict= {"all_snrs":all_snrs, "test_accuracy_noisyMLP":test_accuracy_noisyMLP, "test_accuracy_cleanMLP":test_accuracy_cleanMLP}
savemat(out_CarMod_classify_file + '.mat', mat_dict)
