# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import h5py 
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import random
import copy
from scipy.io import savemat

# %% [markdown]
# ## Load datasets
# 1. Load noisy datasets to train the mimmax_scaler
# 2. Load clean data to train MLPclean
# 3. Load noisy data to train MLPnoisy

# %%
all_snrs= np.arange(-20.0, 11, 5)
all_snrs= np.append(all_snrs, np.inf)
snr_training_weights= np.flip(len(all_snrs)-np.arange(len(all_snrs)))/len(all_snrs)
print(snr_training_weights)

root_data_dir= '../Datasets/CarModPow/PyData/'

# Load clean data 
train_test_dataset = h5py.File(root_data_dir + 'CarMod_data_clean.h5', "r")
data_x_clean_orig = np.array(train_test_dataset["data_CarMod_x"][:]) # your train set features
data_y_clean_orig = np.ravel(np.array(train_test_dataset["data_label_y"][:])) # your train set labels

print(f"pre-shape:data_x_clean_orig={data_x_clean_orig.shape}, data_y_clean_orig={data_y_clean_orig.shape}")
data_x_clean_orig = np.reshape(data_x_clean_orig,(data_x_clean_orig.shape[0],data_x_clean_orig.shape[1]*data_x_clean_orig.shape[2]))
print(f"post-shape:data_x_clean_orig={data_x_clean_orig.shape}, data_y_clean_orig={data_y_clean_orig.shape}")
# data_clean_fnames = np.ravel(np.array(train_test_dataset["data_filename"][:])) # your train set labels

train_inds, test_inds = train_test_split(np.arange(data_x_clean_orig.shape[0]), test_size=0.25, random_state=1)

all_train_x_orig = data_x_clean_orig[train_inds]
all_train_y_orig = data_y_clean_orig[train_inds]

# Load all SNR data 
for snr_value,snr_weight in zip(all_snrs[0:-1], snr_training_weights[0:-1]):
    print(f"SNR={snr_value} dB and weight = {snr_weight}")
    out_CarMod_data_file = root_data_dir + 'CarMod_data_SNR' + snr_value.astype('int').astype('str') + '.h5'    
    cur_dataset = h5py.File(out_CarMod_data_file, "r")
        
    cur_x = np.array(cur_dataset["data_CarMod_x"][:])
    cur_x = np.reshape(cur_x,(cur_x.shape[0],cur_x.shape[1]*cur_x.shape[2]))
    cur_y = np.ravel(np.array(cur_dataset["data_label_y"][:]))
    
    sample_inds_training, _= train_test_split(np.arange(len(train_inds)), test_size= 1-snr_weight, random_state=1)

    all_train_x_orig = np.concatenate((all_train_x_orig, cur_x[train_inds[sample_inds_training]]))
    all_train_y_orig = np.concatenate((all_train_y_orig, cur_y[train_inds[sample_inds_training]]))
    print(f"shape:cur={cur_x.shape},cur_subsamp={len(sample_inds_training)}, full={len(train_inds)}, all_train_x_orig={all_train_x_orig.shape},type={type(cur_x)}")

minmax_scaler = MinMaxScaler()
minmax_scaler.fit(all_train_x_orig)

train_clean_x_norm = minmax_scaler.transform(data_x_clean_orig)
all_train_x_norm = minmax_scaler.transform(all_train_x_orig)

X_train_clean, X_test_clean, y_train_clean, y_test_clean, train_inds, test_inds = train_test_split \
    (train_clean_x_norm, data_y_clean_orig, np.arange(train_clean_x_norm.shape[0]), test_size=0.25, random_state=1)
print(f"Type: X_train_clean={type(X_train_clean)}, y_train_clean={type(y_train_clean)}")
print(f"Shapes: X_train_clean={X_train_clean.shape}, y_train_clean={y_train_clean.shape}, X_test_clean={X_test_clean.shape}, y_test_clean={y_test_clean.shape}")

unq_vals, unq_counts = np.unique(y_train_clean, return_counts=True)
print(dict(zip(unq_vals,unq_counts)))
# Out:
# [0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# pre-shape:data_x_clean_orig=(1605, 67, 9), data_y_clean_orig=(1605,)
# post-shape:data_x_clean_orig=(1605, 603), data_y_clean_orig=(1605,)
# SNR=-20.0 dB and weight = 0.125
# shape:cur=(1605, 603),cur_subsamp=150, full=1203, all_train_x_orig=(1353, 603),type=<class 'numpy.ndarray'>
# SNR=-15.0 dB and weight = 0.25
# shape:cur=(1605, 603),cur_subsamp=300, full=1203, all_train_x_orig=(1653, 603),type=<class 'numpy.ndarray'>
# SNR=-10.0 dB and weight = 0.375
# shape:cur=(1605, 603),cur_subsamp=451, full=1203, all_train_x_orig=(2104, 603),type=<class 'numpy.ndarray'>
# SNR=-5.0 dB and weight = 0.5
# shape:cur=(1605, 603),cur_subsamp=601, full=1203, all_train_x_orig=(2705, 603),type=<class 'numpy.ndarray'>
# SNR=0.0 dB and weight = 0.625
# shape:cur=(1605, 603),cur_subsamp=751, full=1203, all_train_x_orig=(3456, 603),type=<class 'numpy.ndarray'>
# SNR=5.0 dB and weight = 0.75
# shape:cur=(1605, 603),cur_subsamp=902, full=1203, all_train_x_orig=(4358, 603),type=<class 'numpy.ndarray'>
# SNR=10.0 dB and weight = 0.875
# shape:cur=(1605, 603),cur_subsamp=1052, full=1203, all_train_x_orig=(5410, 603),type=<class 'numpy.ndarray'>
# Type: X_train_clean=<class 'numpy.ndarray'>, y_train_clean=<class 'numpy.ndarray'>
# Shapes: X_train_clean=(1203, 603), y_train_clean=(1203,), X_test_clean=(402, 603), y_test_clean=(402,)
# {0: 327, 1: 191, 2: 285, 3: 328, 4: 72}

# %% [markdown]
# ## Model #1: An SVM model (rbf kernels seem to work the best)

# %%
svm_model = svm.SVC(kernel='rbf').fit(X_train_clean, y_train_clean)
y_train_pred = svm_model.predict(X_train_clean)
y_test_pred = svm_model.predict(X_test_clean)

print(f"Unique values in y_test_pred={np.unique(y_test_pred)}")
print(f"Unique values in y_train_clean={np.unique(y_train_clean)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_clean==y_train_pred)/len(y_train_pred)}\n Testing accuracy={np.sum(y_test_clean==y_test_pred)/len(y_test_pred)}\n")
# Out:
# Unique values in y_test_pred=[0 1 2 3 4]
# Unique values in y_train_clean=[0 1 2 3 4]
# Training accuracy=0.9875311720698254
#  Testing accuracy=0.9701492537313433

# %% [markdown]
# ## Model #2. Train an MLP on clean calls

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPclean = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPclean.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy'],
)

# Fit the model 
MLPclean.fit(
    X_train_clean,y_train_clean,
    epochs=200
)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 1s 1ms/step - loss: 0.7250 - accuracy: 0.7722
# Epoch 2/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.2182 - accuracy: 0.9468
# Epoch 3/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.1468 - accuracy: 0.9651
# Epoch 4/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.1092 - accuracy: 0.9734
# Epoch 5/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0961 - accuracy: 0.9792
# Epoch 6/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9817
# Epoch 7/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0724 - accuracy: 0.9817
# Epoch 8/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9817
# Epoch 9/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9734
# Epoch 10/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0629 - accuracy: 0.9834
# Epoch 11/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0651 - accuracy: 0.9825
# Epoch 12/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 0.9776
# Epoch 13/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0444 - accuracy: 0.9900
# Epoch 14/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0410 - accuracy: 0.9925
# Epoch 15/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9925
# Epoch 16/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0471 - accuracy: 0.9875
# Epoch 17/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9909
# Epoch 18/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 0.9917
# Epoch 19/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9958
# Epoch 20/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 0.9958
# Epoch 21/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 0.9950
# Epoch 22/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0273 - accuracy: 0.9942
# Epoch 23/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 0.9958
# Epoch 24/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9967
# Epoch 25/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 0.9950
# Epoch 26/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.9967
# Epoch 27/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.9958
# Epoch 28/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9967
# Epoch 29/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.9967
# Epoch 30/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 0.9967
# Epoch 31/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0167 - accuracy: 0.9958
# Epoch 32/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 0.9942
# Epoch 33/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 0.9967
# Epoch 34/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9975
# Epoch 35/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9958
# Epoch 36/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9975
# Epoch 37/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9975
# Epoch 38/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9983
# Epoch 39/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 0.9983
# Epoch 40/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 0.9975
# Epoch 41/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 0.9975
# Epoch 42/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 0.9983
# Epoch 43/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.9992
# Epoch 44/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 45/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.9992
# Epoch 46/200
# 38/38 [==============================] - 0s 988us/step - loss: 0.0065 - accuracy: 0.9992
# Epoch 47/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.9992
# Epoch 48/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9992
# Epoch 49/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 0.9942
# Epoch 50/200
# 38/38 [==============================] - 0s 961us/step - loss: 0.0308 - accuracy: 0.9859
# Epoch 51/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0883 - accuracy: 0.9776
# Epoch 52/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9784
# Epoch 53/200
# 38/38 [==============================] - 0s 961us/step - loss: 0.0690 - accuracy: 0.9800
# Epoch 54/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 0.9900
# Epoch 55/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.9967
# Epoch 56/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0117 - accuracy: 0.9967
# Epoch 57/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.9967
# Epoch 58/200
# 38/38 [==============================] - 0s 988us/step - loss: 0.0080 - accuracy: 0.9975
# Epoch 59/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9983
# Epoch 60/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 0.9983
# Epoch 61/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 0.9983
# Epoch 62/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9983
# Epoch 63/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.9992
# Epoch 64/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 0.9992
# Epoch 65/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 0.9983
# Epoch 66/200
# 38/38 [==============================] - 0s 989us/step - loss: 0.0042 - accuracy: 0.9992
# Epoch 67/200
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2460e-04 - accuracy: 1.0000
# Epoch 145/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9640e-04 - accuracy: 1.0000
# Epoch 146/200
# 38/38 [==============================] - 0s 1ms/step - loss: 2.5136e-04 - accuracy: 1.0000
# Epoch 147/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.8265e-04 - accuracy: 1.0000
# Epoch 148/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9873e-04 - accuracy: 1.0000
# Epoch 149/200
# 38/38 [==============================] - 0s 1ms/step - loss: 2.0571e-04 - accuracy: 1.0000
# Epoch 150/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9092e-04 - accuracy: 1.0000
# Epoch 151/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9736e-04 - accuracy: 1.0000
# Epoch 152/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.7578e-04 - accuracy: 1.0000
# Epoch 153/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.5296e-04 - accuracy: 1.0000
# Epoch 154/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.6395e-04 - accuracy: 1.0000
# Epoch 155/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.6838e-04 - accuracy: 1.0000
# Epoch 156/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3546e-04 - accuracy: 1.0000
# Epoch 157/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.8205e-04 - accuracy: 1.0000
# Epoch 158/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.8890e-04 - accuracy: 1.0000
# Epoch 159/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.4706e-04 - accuracy: 1.0000
# Epoch 160/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.4591e-04 - accuracy: 1.0000
# Epoch 161/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3466e-04 - accuracy: 1.0000
# Epoch 162/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.4204e-04 - accuracy: 1.0000
# Epoch 163/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3151e-04 - accuracy: 1.0000
# Epoch 164/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1971e-04 - accuracy: 1.0000
# Epoch 165/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2533e-04 - accuracy: 1.0000
# Epoch 166/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1779e-04 - accuracy: 1.0000
# Epoch 167/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1850e-04 - accuracy: 1.0000
# Epoch 168/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1273e-04 - accuracy: 1.0000
# Epoch 169/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1385e-04 - accuracy: 1.0000
# Epoch 170/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1056e-04 - accuracy: 1.0000
# Epoch 171/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0069e-04 - accuracy: 1.0000
# Epoch 172/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1321e-04 - accuracy: 1.0000
# Epoch 173/200
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2426e-04 - accuracy: 1.0000
# Epoch 174/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.8354e-05 - accuracy: 1.0000
# Epoch 175/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.9115e-05 - accuracy: 1.0000
# Epoch 176/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.0530e-05 - accuracy: 1.0000
# Epoch 177/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.7370e-05 - accuracy: 1.0000
# Epoch 178/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.4352e-05 - accuracy: 1.0000
# Epoch 179/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.1369e-05 - accuracy: 1.0000
# Epoch 180/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.5309e-05 - accuracy: 1.0000
# Epoch 181/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.0197e-05 - accuracy: 1.0000
# Epoch 182/200
# 38/38 [==============================] - 0s 1ms/step - loss: 8.1352e-05 - accuracy: 1.0000
# Epoch 183/200
# 38/38 [==============================] - 0s 1ms/step - loss: 8.2317e-05 - accuracy: 1.0000
# Epoch 184/200
# 38/38 [==============================] - 0s 1ms/step - loss: 7.4894e-05 - accuracy: 1.0000
# Epoch 185/200
# 38/38 [==============================] - 0s 1ms/step - loss: 7.7366e-05 - accuracy: 1.0000
# Epoch 186/200
# 38/38 [==============================] - 0s 1ms/step - loss: 7.8547e-05 - accuracy: 1.0000
# Epoch 187/200
# 38/38 [==============================] - 0s 1ms/step - loss: 9.6427e-05 - accuracy: 1.0000
# Epoch 188/200
# 38/38 [==============================] - 0s 1ms/step - loss: 7.3537e-05 - accuracy: 1.0000
# Epoch 189/200
# 38/38 [==============================] - 0s 1ms/step - loss: 7.2891e-05 - accuracy: 1.0000
# Epoch 190/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.9766e-05 - accuracy: 1.0000
# Epoch 191/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.8464e-05 - accuracy: 1.0000
# Epoch 192/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.6706e-05 - accuracy: 1.0000
# Epoch 193/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.7115e-05 - accuracy: 1.0000
# Epoch 194/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.4422e-05 - accuracy: 1.0000
# Epoch 195/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.4630e-05 - accuracy: 1.0000
# Epoch 196/200
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8016e-05 - accuracy: 1.0000
# Epoch 197/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.0471e-05 - accuracy: 1.0000
# Epoch 198/200
# 38/38 [==============================] - 0s 1ms/step - loss: 5.4215e-05 - accuracy: 1.0000
# Epoch 199/200
# 38/38 [==============================] - 0s 1ms/step - loss: 5.5130e-05 - accuracy: 1.0000
# Epoch 200/200
# 38/38 [==============================] - 0s 1ms/step - loss: 6.0528e-05 - accuracy: 1.0000

# %% [markdown]
# ## Test MLP accuracy for training and testing

# %%
y_train_pred_NN = np.argmax(MLPclean.predict(X_train_clean), axis=1)
y_test_pred_NN = np.argmax(MLPclean.predict(X_test_clean), axis=1)

print(f"Unique values in y_train_clean={np.unique(y_train_pred_NN)}")
print(f"Unique values in y_test_pred={np.unique(y_test_pred_NN)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred_NN, color = "orangered")
ax[1].set_xlabel("Call numbers")

train_accuracy_cleanMLP = np.sum(y_train_clean==y_train_pred_NN)/len(y_train_clean)
print(f"Training accuracy={train_accuracy_cleanMLP}\n Testing accuracy={np.sum(y_test_clean==y_test_pred_NN)/len(y_test_clean)}\n")
# Out:
# 38/38 [==============================] - 0s 704us/step
# 13/13 [==============================] - 0s 793us/step
# Unique values in y_train_clean=[0 1 2 3 4]
# Unique values in y_test_pred=[0 1 2 3 4]
# Training accuracy=1.0
#  Testing accuracy=0.9800995024875622

# %% [markdown]
# ## Model #3. MLP cleaned on noisy calls

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPnoisy = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPnoisy.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy'],
)

# Fit the model 
MLPnoisy.fit(
    all_train_x_norm, all_train_y_orig,
    epochs=50,
)
# Out:
# Epoch 1/50
# 170/170 [==============================] - 1s 1ms/step - loss: 0.7172 - accuracy: 0.7482
# Epoch 2/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.4189 - accuracy: 0.8571
# Epoch 3/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.3616 - accuracy: 0.8780
# Epoch 4/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.3270 - accuracy: 0.8863
# Epoch 5/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2872 - accuracy: 0.9048
# Epoch 6/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2796 - accuracy: 0.9070
# Epoch 7/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2607 - accuracy: 0.9133
# Epoch 8/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 0.9087
# Epoch 9/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2627 - accuracy: 0.9111
# Epoch 10/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.9192
# Epoch 11/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9216
# Epoch 12/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9159
# Epoch 13/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2211 - accuracy: 0.9248
# Epoch 14/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2255 - accuracy: 0.9216
# Epoch 15/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2191 - accuracy: 0.9253
# Epoch 16/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2130 - accuracy: 0.9262
# Epoch 17/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2151 - accuracy: 0.9307
# Epoch 18/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2141 - accuracy: 0.9244
# Epoch 19/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9359
# Epoch 20/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9307
# Epoch 21/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9329
# Epoch 22/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2100 - accuracy: 0.9298
# Epoch 23/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2082 - accuracy: 0.9307
# Epoch 24/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9357
# Epoch 25/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1990 - accuracy: 0.9344
# Epoch 26/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1967 - accuracy: 0.9333
# Epoch 27/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1900 - accuracy: 0.9348
# Epoch 28/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9275
# Epoch 29/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2198 - accuracy: 0.9261
# Epoch 30/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9416
# Epoch 31/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.2028 - accuracy: 0.9309
# Epoch 32/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1793 - accuracy: 0.9396
# Epoch 33/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9381
# Epoch 34/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1693 - accuracy: 0.9403
# Epoch 35/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 0.9414
# Epoch 36/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9342
# Epoch 37/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1891 - accuracy: 0.9384
# Epoch 38/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1695 - accuracy: 0.9445
# Epoch 39/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9360
# Epoch 40/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1805 - accuracy: 0.9397
# Epoch 41/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1646 - accuracy: 0.9457
# Epoch 42/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1637 - accuracy: 0.9453
# Epoch 43/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 0.9479
# Epoch 44/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1630 - accuracy: 0.9442
# Epoch 45/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9455
# Epoch 46/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9368
# Epoch 47/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9414
# Epoch 48/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1836 - accuracy: 0.9390
# Epoch 49/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1566 - accuracy: 0.9471
# Epoch 50/50
# 170/170 [==============================] - 0s 1ms/step - loss: 0.1556 - accuracy: 0.9481

# %% [markdown]
# ## Test in different SNRs

# %%
def test_MLP_snr(MLPmodel, minmax_scaler, snr_value, test_inds_clean):
    root_out_dir= '../Datasets/CarModPow/PyData/'
    if np.isinf(snr_value):
        out_CarMod_data_file = root_data_dir + 'CarMod_data_clean.h5'
    else:
        out_CarMod_data_file = root_out_dir + 'CarMod_data_SNR' + snr_value.astype('int').astype('str') + '.h5'
    cur_snr_dataset = h5py.File(out_CarMod_data_file, "r")
    print(cur_snr_dataset)
    data_x_orig = np.array(cur_snr_dataset["data_CarMod_x"][:]) # your train set features
    data_x_orig= np.reshape(data_x_orig, (data_x_orig.shape[0],data_x_orig.shape[1]*data_x_orig.shape[2]))
    data_y_orig = np.ravel(np.array(cur_snr_dataset["data_label_y"][:])) # your train set labels
    # data_fnames = np.ravel(np.array(cur_snr_dataset["data_filename"][:])) # your train set labels
    data_x_norm = minmax_scaler.transform(data_x_orig)

    X_test = data_x_norm[test_inds]
    y_test = data_y_orig[test_inds]
    # fName_test= data_fnames[test_inds]
    
    # rand_int = random.randint(0, len(test_fnames_clean))
    # clean_name = test_fnames_clean[rand_int].decode("utf-8")
    # noisy_name= fName_test[rand_int].decode("utf-8")

    # print(f"fnumber={rand_int} |-| clean={clean_name}|noisy={noisy_name}")
    # clean_name= clean_name[clean_name.rfind('/')+1:-3]
    # noisy_name= noisy_name[noisy_name.rfind('/')+1:-3]
    # if clean_name!=noisy_name:
    #     print("Should be same")
    y_test_pred_NN = np.argmax(MLPmodel.predict(X_test), axis=1)
    accuracy = np.sum(y_test==y_test_pred_NN)/len(y_test_clean)
    print(f"[SNR={snr_value} dB] Accuracy={accuracy}\n")
    
    return accuracy

y_train_pred_NN = np.argmax(MLPnoisy.predict(all_train_x_norm), axis=1)
train_accuracy_noisyMLP = np.sum(all_train_y_orig==y_train_pred_NN)/len(all_train_y_orig)

test_accuracy_cleanMLP = np.zeros(all_snrs.shape)
test_accuracy_noisyMLP = np.zeros(all_snrs.shape)
for snr_value,iter in zip(all_snrs,range(len(all_snrs))):
    test_accuracy_cleanMLP[iter]= test_MLP_snr(MLPclean, minmax_scaler, snr_value, test_inds)
    test_accuracy_noisyMLP[iter]= test_MLP_snr(MLPnoisy, minmax_scaler, snr_value, test_inds)
    # print(f"SNR={snr_value} dB | Accuracy={test_accuracy[iter]}")
# Out:
# 170/170 [==============================] - 0s 708us/step
# <HDF5 file "CarMod_data_SNR-20.h5" (mode r)>
# 13/13 [==============================] - 0s 709us/step
# [SNR=-20.0 dB] Accuracy=0.05472636815920398
#
# <HDF5 file "CarMod_data_SNR-20.h5" (mode r)>
# 13/13 [==============================] - 0s 794us/step
# [SNR=-20.0 dB] Accuracy=0.38308457711442784
#
# <HDF5 file "CarMod_data_SNR-15.h5" (mode r)>
# 13/13 [==============================] - 0s 876us/step
# [SNR=-15.0 dB] Accuracy=0.06467661691542288
#
# <HDF5 file "CarMod_data_SNR-15.h5" (mode r)>
# 13/13 [==============================] - 0s 876us/step
# [SNR=-15.0 dB] Accuracy=0.6044776119402985
#
# <HDF5 file "CarMod_data_SNR-10.h5" (mode r)>
# 13/13 [==============================] - 0s 709us/step
# [SNR=-10.0 dB] Accuracy=0.07960199004975124
#
# <HDF5 file "CarMod_data_SNR-10.h5" (mode r)>
# 13/13 [==============================] - 0s 793us/step
# [SNR=-10.0 dB] Accuracy=0.8084577114427861
#
# <HDF5 file "CarMod_data_SNR-5.h5" (mode r)>
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-5.0 dB] Accuracy=0.12437810945273632
#
# <HDF5 file "CarMod_data_SNR-5.h5" (mode r)>
# 13/13 [==============================] - 0s 918us/step
# [SNR=-5.0 dB] Accuracy=0.8955223880597015
#
# <HDF5 file "CarMod_data_SNR0.h5" (mode r)>
# 13/13 [==============================] - 0s 751us/step
# [SNR=0.0 dB] Accuracy=0.26865671641791045
#
# <HDF5 file "CarMod_data_SNR0.h5" (mode r)>
# 13/13 [==============================] - 0s 793us/step
# [SNR=0.0 dB] Accuracy=0.9303482587064676
#
# <HDF5 file "CarMod_data_SNR5.h5" (mode r)>
# 13/13 [==============================] - 0s 876us/step
# [SNR=5.0 dB] Accuracy=0.7562189054726368
#
# <HDF5 file "CarMod_data_SNR5.h5" (mode r)>
# 13/13 [==============================] - 0s 793us/step
# [SNR=5.0 dB] Accuracy=0.9651741293532339
#
# <HDF5 file "CarMod_data_SNR10.h5" (mode r)>
# 13/13 [==============================] - 0s 794us/step
# [SNR=10.0 dB] Accuracy=0.9353233830845771
#
# <HDF5 file "CarMod_data_SNR10.h5" (mode r)>
# 13/13 [==============================] - 0s 793us/step
# [SNR=10.0 dB] Accuracy=0.945273631840796
#
# <HDF5 file "CarMod_data_clean.h5" (mode r)>
# 13/13 [==============================] - 0s 710us/step
# [SNR=inf dB] Accuracy=0.9800995024875622
#
# <HDF5 file "CarMod_data_clean.h5" (mode r)>
# 13/13 [==============================] - 0s 753us/step
# [SNR=inf dB] Accuracy=0.9402985074626866

# %% [markdown]
# ## Plot results

# %%
doSave = 0
plot_snr= copy.deepcopy(all_snrs)
plot_snr[np.isinf(plot_snr)] = 20
plot_snr = np.append(plot_snr[:-1], [15, plot_snr[-1], 25, 30])
plot_snr_label = [str(item.astype('int')) for item in plot_snr[:-4]] + [''] + ['$\infty$'] + [''] + ['Training']
plt_accuracy_clean = np.append(test_accuracy_cleanMLP[:-1], [np.nan, test_accuracy_cleanMLP[-1], np.nan, train_accuracy_cleanMLP])
plt_accuracy_noisy = np.append(test_accuracy_noisyMLP[:-1], [np.nan, test_accuracy_noisyMLP[-1], np.nan, train_accuracy_noisyMLP])

plt.plot(plot_snr, plt_accuracy_clean, 'o-', label="Clean-trained")
plt.plot(plot_snr, plt_accuracy_noisy, 'o-', label="Noise-trained")
plt.xlabel("SNR (dB)")
plt.ylabel("Accuracy")
plt.title("Carrier (place) + modulation ")
plt.legend(loc='lower right')
plt.xticks(ticks=plot_snr, labels=plot_snr_label)

out_CarMod_classify_file = root_data_dir + 'CarMod_classify_out'
if doSave:
    np.savez(out_CarMod_classify_file + '.npz', all_snrs=all_snrs, \
        minmax_scaler=minmax_scaler, MLPclean=MLPclean, MLPnoisy=MLPnoisy, \
        train_accuracy_cleanMLP=train_accuracy_cleanMLP, train_accuracy_noisyMLP=train_accuracy_noisyMLP, \
        test_accuracy_cleanMLP=test_accuracy_cleanMLP, test_accuracy_noisyMLP=test_accuracy_noisyMLP) 
    
    mat_dict= {"all_snrs":all_snrs, "train_accuracy_cleanMLP":train_accuracy_cleanMLP, "train_accuracy_noisyMLP":train_accuracy_noisyMLP, \
            "test_accuracy_cleanMLP":test_accuracy_cleanMLP, "test_accuracy_noisyMLP":test_accuracy_noisyMLP}
    savemat(out_CarMod_classify_file + '.mat', mat_dict)
