# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import h5py 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical

# %% [markdown]
# Load dataset

# %%
train_dataset = h5py.File('../Datasets/mps_gp_sgram/ml_data_CNN/all_dsMPS_data.h5', "r")
print(train_dataset)

train_set_x_orig = np.array(train_dataset["data_dsMPS_x"][:]) # your train set features
train_set_y_orig = to_categorical(np.ravel(np.array(train_dataset["data_label_y"][:]))) # your train set labels

# train_set_x_norm= train_set_x_orig
# nsamples, nx, ny = train_set_x_orig.shape
# standard_scaler = StandardScaler()
# standard_scaler.fit(train_set_x_orig.reshape((nsamples,nx*ny)))
# train_set_x_norm = standard_scaler.transform(train_set_x_orig)

X_train, X_test, y_train, y_test = train_test_split(train_set_x_orig, train_set_y_orig,test_size=0.25, random_state=1)
print(f"Type: X_train={type(X_train)}, y_train={type(y_train)}")
print(f"Shapes: X_train={X_train.shape}, y_train={y_train.shape}, X_test={X_test.shape}, y_test={y_test.shape}")

unq_vals, unq_counts = np.unique(y_train, return_counts=True)
print(dict(zip(unq_vals,unq_counts)))
# print(X_train)
# Out:
# <HDF5 file "all_dsMPS_data.h5" (mode r)>
# Type: X_train=<class 'numpy.ndarray'>, y_train=<class 'numpy.ndarray'>
# Shapes: X_train=(1203, 80, 69), y_train=(1203, 5), X_test=(402, 80, 69), y_test=(402, 5)
# {0.0: 4812, 1.0: 1203}

# %% [markdown]
# Train a fully connected NN followed by a softmax

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
CNNmodel = tf.keras.Sequential([
    ## ZeroPadding2D with padding 3, input shape of 80 x 69 x 1
    ## Conv2D with 32 5x5 filters and stride of 1
    ## BatchNormalization for axis 3
    ## ReLU
    ## Max Pooling 2D with default parameters
    ## Flatten layer
    ## Dense layer with 1 unit for output & 'sigmoid' activation            
        
    # YOUR CODE STARTS HERE
    tf.keras.layers.ZeroPadding2D(padding=3,input_shape=(80,69,1)),
    tf.keras.layers.Conv2D(filters=16, kernel_size=(5,5),padding='same', strides=(1,1)),
    tf.keras.layers.BatchNormalization(axis=-1),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Flatten(), 
    tf.keras.layers.Dense(units=5, activation='softmax'),
    # YOUR CODE ENDS HERE
    ])

CNNmodel.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
CNNmodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d_3 (ZeroPaddi  (None, 86, 75, 1)        0
#  ng2D)
#
#  conv2d_3 (Conv2D)           (None, 86, 75, 16)        416
#
#  batch_normalization_3 (Batc  (None, 86, 75, 16)       64
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 86, 75, 16)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 37, 16)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 25456)             0
#
#  dense_3 (Dense)             (None, 5)                 127285
#
# =================================================================
# Total params: 127,765
# Trainable params: 127,733
# Non-trainable params: 32
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)
history = CNNmodel.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 11ms/step - loss: 3.9278 - accuracy: 0.4771 - val_loss: 24.6760 - val_accuracy: 0.1045
# Epoch 2/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5253 - accuracy: 0.8196 - val_loss: 10.7873 - val_accuracy: 0.1866
# Epoch 3/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.3111 - accuracy: 0.8986 - val_loss: 6.2169 - val_accuracy: 0.3905
# Epoch 4/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.2385 - accuracy: 0.9368 - val_loss: 3.6188 - val_accuracy: 0.4527
# Epoch 5/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1952 - accuracy: 0.9568 - val_loss: 3.5650 - val_accuracy: 0.3532
# Epoch 6/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1764 - accuracy: 0.9593 - val_loss: 2.0479 - val_accuracy: 0.4776
# Epoch 7/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1520 - accuracy: 0.9543 - val_loss: 0.6028 - val_accuracy: 0.7438
# Epoch 8/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.2155 - accuracy: 0.9360 - val_loss: 0.4759 - val_accuracy: 0.8358
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1769 - accuracy: 0.9460 - val_loss: 3.2183 - val_accuracy: 0.5821
# Epoch 10/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1068 - accuracy: 0.9709 - val_loss: 8.5755 - val_accuracy: 0.1891
# Epoch 11/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0474 - accuracy: 0.9933 - val_loss: 3.1880 - val_accuracy: 0.3831
# Epoch 12/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0624 - accuracy: 0.9825 - val_loss: 10.0851 - val_accuracy: 0.1343
# Epoch 13/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0550 - accuracy: 0.9884 - val_loss: 9.5680 - val_accuracy: 0.0821
# Epoch 14/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0364 - accuracy: 0.9900 - val_loss: 10.5009 - val_accuracy: 0.1567
# Epoch 15/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0357 - accuracy: 0.9917 - val_loss: 5.6250 - val_accuracy: 0.3010
# Epoch 16/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9958 - val_loss: 4.3828 - val_accuracy: 0.3881
# Epoch 17/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 0.9967 - val_loss: 4.2221 - val_accuracy: 0.3955
# Epoch 18/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0306 - accuracy: 0.9942 - val_loss: 4.0351 - val_accuracy: 0.3831
# Epoch 19/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0289 - accuracy: 0.9942 - val_loss: 2.2118 - val_accuracy: 0.6045
# Epoch 20/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 0.9958 - val_loss: 3.2503 - val_accuracy: 0.5100
# Epoch 21/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0361 - accuracy: 0.9925 - val_loss: 3.9006 - val_accuracy: 0.2985
# Epoch 22/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 1.1406 - val_accuracy: 0.7388
# Epoch 23/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0307 - accuracy: 0.9925 - val_loss: 15.7162 - val_accuracy: 0.0622
# Epoch 24/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 0.9557 - val_accuracy: 0.7313
# Epoch 25/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0293 - accuracy: 0.9917 - val_loss: 17.8935 - val_accuracy: 0.1816
# Epoch 26/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0328 - accuracy: 0.9884 - val_loss: 8.2702 - val_accuracy: 0.3682
# Epoch 27/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 1.5660 - val_accuracy: 0.6940
# Epoch 28/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 3.0046 - val_accuracy: 0.5796
# Epoch 29/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0303 - accuracy: 0.9917 - val_loss: 3.1685 - val_accuracy: 0.4801
# Epoch 30/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0292 - accuracy: 0.9884 - val_loss: 0.8868 - val_accuracy: 0.7512
# Epoch 31/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0451 - accuracy: 0.9817 - val_loss: 3.3306 - val_accuracy: 0.4652
# Epoch 32/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 0.9875 - val_loss: 0.4370 - val_accuracy: 0.8682
# Epoch 33/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0502 - accuracy: 0.9825 - val_loss: 32.7759 - val_accuracy: 0.0697
# Epoch 34/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0556 - accuracy: 0.9784 - val_loss: 11.4539 - val_accuracy: 0.3284
# Epoch 35/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0450 - accuracy: 0.9834 - val_loss: 6.0100 - val_accuracy: 0.2313
# Epoch 36/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0508 - accuracy: 0.9800 - val_loss: 4.8004 - val_accuracy: 0.4279
# Epoch 37/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 0.9884 - val_loss: 23.3080 - val_accuracy: 0.0771
# Epoch 38/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0365 - accuracy: 0.9859 - val_loss: 5.5245 - val_accuracy: 0.3209
# Epoch 39/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0583 - accuracy: 0.9759 - val_loss: 20.9874 - val_accuracy: 0.0622
# Epoch 40/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0823 - accuracy: 0.9734 - val_loss: 30.7287 - val_accuracy: 0.1269
# Epoch 41/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1247 - accuracy: 0.9526 - val_loss: 19.3686 - val_accuracy: 0.1343
# Epoch 42/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0314 - accuracy: 0.9884 - val_loss: 1.4319 - val_accuracy: 0.7090
# Epoch 43/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 1.0750 - val_accuracy: 0.8109
# Epoch 44/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9983 - val_loss: 0.2806 - val_accuracy: 0.9279
# Epoch 45/100
# 38/38 [==============================] - 0s 7ms/step - loss: 4.9009e-04 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9204
# Epoch 46/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.2496e-04 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9328
# Epoch 47/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.1431e-04 - accuracy: 1.0000 - val_loss: 0.2368 - val_accuracy: 0.9378
# Epoch 48/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.1009e-04 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9403
# Epoch 49/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.0691e-04 - accuracy: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9428
# Epoch 50/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.0412e-04 - accuracy: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9428
# Epoch 51/100
# 38/38 [==============================] - 0s 7ms/step - loss: 1.0160e-04 - accuracy: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9403
# Epoch 52/100
# 38/38 [==============================] - 0s 7ms/step - loss: 9.9294e-05 - accuracy: 1.0000 - val_loss: 0.2424 - val_accuracy: 0.9403
# Epoch 53/100
# 38/38 [==============================] - 0s 7ms/step - loss: 9.7106e-05 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9428
# Epoch 54/100
# 38/38 [==============================] - 0s 7ms/step - loss: 9.5024e-05 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9428
# Epoch 55/100
# 38/38 [==============================] - 0s 7ms/step - loss: 9.3049e-05 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9428
# Epoch 56/100
# 38/38 [==============================] - 0s 7ms/step - loss: 9.1171e-05 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9428
# Epoch 57/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.9378e-05 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9403
# Epoch 58/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.7678e-05 - accuracy: 1.0000 - val_loss: 0.2459 - val_accuracy: 0.9403
# Epoch 59/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.6086e-05 - accuracy: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.9403
# Epoch 60/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.4592e-05 - accuracy: 1.0000 - val_loss: 0.2465 - val_accuracy: 0.9403
# Epoch 61/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.3163e-05 - accuracy: 1.0000 - val_loss: 0.2468 - val_accuracy: 0.9403
# Epoch 62/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.1791e-05 - accuracy: 1.0000 - val_loss: 0.2471 - val_accuracy: 0.9403
# Epoch 63/100
# 38/38 [==============================] - 0s 7ms/step - loss: 8.0484e-05 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9403
# Epoch 64/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.9227e-05 - accuracy: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9428
# Epoch 65/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.8015e-05 - accuracy: 1.0000 - val_loss: 0.2475 - val_accuracy: 0.9428
# Epoch 66/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.6841e-05 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.9428
# Epoch 67/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.5705e-05 - accuracy: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.9428
# Epoch 68/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.4603e-05 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9428
# Epoch 69/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.3526e-05 - accuracy: 1.0000 - val_loss: 0.2483 - val_accuracy: 0.9428
# Epoch 70/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.2469e-05 - accuracy: 1.0000 - val_loss: 0.2485 - val_accuracy: 0.9428
# Epoch 71/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.1438e-05 - accuracy: 1.0000 - val_loss: 0.2487 - val_accuracy: 0.9428
# Epoch 72/100
# 38/38 [==============================] - 0s 7ms/step - loss: 7.0430e-05 - accuracy: 1.0000 - val_loss: 0.2489 - val_accuracy: 0.9428
# Epoch 73/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.9451e-05 - accuracy: 1.0000 - val_loss: 0.2490 - val_accuracy: 0.9428
# Epoch 74/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.8489e-05 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9428
# Epoch 75/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.7547e-05 - accuracy: 1.0000 - val_loss: 0.2494 - val_accuracy: 0.9428
# Epoch 76/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.6632e-05 - accuracy: 1.0000 - val_loss: 0.2495 - val_accuracy: 0.9428
# Epoch 77/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.5744e-05 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9428
# Epoch 78/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.4876e-05 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.9428
# Epoch 79/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.4033e-05 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9428
# Epoch 80/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.3206e-05 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9428
# Epoch 81/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.2398e-05 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9428
# Epoch 82/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.1608e-05 - accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9428
# Epoch 83/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.0831e-05 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9428
# Epoch 84/100
# 38/38 [==============================] - 0s 7ms/step - loss: 6.0065e-05 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9403
# Epoch 85/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.9311e-05 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9403
# Epoch 86/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.8573e-05 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9403
# Epoch 87/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.7850e-05 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9403
# Epoch 88/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.7141e-05 - accuracy: 1.0000 - val_loss: 0.2506 - val_accuracy: 0.9403
# Epoch 89/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.6444e-05 - accuracy: 1.0000 - val_loss: 0.2507 - val_accuracy: 0.9403
# Epoch 90/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.5757e-05 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9403
# Epoch 91/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.5078e-05 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9403
# Epoch 92/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.4411e-05 - accuracy: 1.0000 - val_loss: 0.2511 - val_accuracy: 0.9403
# Epoch 93/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.3756e-05 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.9403
# Epoch 94/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.3106e-05 - accuracy: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9403
# Epoch 95/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.2460e-05 - accuracy: 1.0000 - val_loss: 0.2515 - val_accuracy: 0.9403
# Epoch 96/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.1827e-05 - accuracy: 1.0000 - val_loss: 0.2516 - val_accuracy: 0.9403
# Epoch 97/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.1202e-05 - accuracy: 1.0000 - val_loss: 0.2516 - val_accuracy: 0.9403
# Epoch 98/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.0584e-05 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9403
# Epoch 99/100
# 38/38 [==============================] - 0s 7ms/step - loss: 4.9972e-05 - accuracy: 1.0000 - val_loss: 0.2518 - val_accuracy: 0.9403
# Epoch 100/100
# 38/38 [==============================] - 0s 7ms/step - loss: 4.9367e-05 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9403

# %% [markdown]
# Check output of NN model

# %%
y_train_pred_NN = np.argmax(CNNmodel.predict(X_train), axis=1)
y_test_pred_NN = np.argmax(CNNmodel.predict(X_test), axis=1)
y_train_numeric= np.argmax(y_train, axis=1)
y_test_numeric= np.argmax(y_test, axis=1)

print(f"Unique values in y_train_pred_NN={np.unique(y_train_pred_NN)}")
print(f"Unique values in y_test_pred_NN={np.unique(y_test_pred_NN)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_numeric)
ax[1].plot(y_train_numeric-y_train_pred_NN, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_numeric==y_train_pred_NN)/len(y_train)}\n Testing accuracy={np.sum(y_test_numeric==y_test_pred_NN)/len(y_test_numeric)}\n")
# Out:
# 38/38 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 2ms/step
# Unique values in y_train_pred_NN=[0 1 2 3 4]
# Unique values in y_test_pred_NN=[0 1 2 3 4]
# Training accuracy=1.0
#  Testing accuracy=0.9402985074626866
