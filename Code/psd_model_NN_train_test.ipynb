# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import h5py 
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import random
import copy 
from scipy.io import savemat
from sklearn import metrics as skmetric

# %% [markdown]
# ## Load datasets
# 1. Load noisy datasets to train the mimmax_scaler
# 2. Load clean data to train MLPclean
# 3. Load noisy data to train MLPnoisy

# %%
all_snrs= np.arange(-20.0, 11, 5)
all_snrs= np.append(all_snrs, np.inf)
snr_training_weights= np.flip(len(all_snrs)-np.arange(len(all_snrs)))/len(all_snrs)
print(snr_training_weights)

root_data_dir= 'D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/PyData/'


# Load clean data 
train_test_dataset = h5py.File(root_data_dir + 'PSD_data_clean.h5', "r")
data_x_clean_orig = np.array(train_test_dataset["data_psd_x"][:]) # your train set features
data_y_clean_orig = np.ravel(np.array(train_test_dataset["data_label_y"][:])) # your train set labels
data_clean_fnames = np.ravel(np.array(train_test_dataset["data_filename"][:])) # your train set labels

train_inds, test_inds = train_test_split(np.arange(data_x_clean_orig.shape[0]), test_size=0.25, random_state=1)

all_train_x_orig = data_x_clean_orig[train_inds,:]
all_train_y_orig = data_y_clean_orig[train_inds]

# Load all SNR data 
for snr_value,snr_weight in zip(all_snrs[0:-1], snr_training_weights[0:-1]):
    print(f"SNR={snr_value} dB and weight = {snr_weight}")
    out_psd_data_file = root_data_dir + 'PSD_data_SNR' + snr_value.astype('int').astype('str') + '.h5'    
    cur_dataset = h5py.File(out_psd_data_file, "r")
        
    cur_x = np.array(cur_dataset["data_psd_x"][:])
    cur_y = np.ravel(np.array(cur_dataset["data_label_y"][:]))
    
    sample_inds_training, _= train_test_split(np.arange(len(train_inds)), test_size= 1-snr_weight, random_state=1)

    all_train_x_orig = np.concatenate((all_train_x_orig, cur_x[train_inds[sample_inds_training],:]), axis=0)
    all_train_y_orig = np.concatenate((all_train_y_orig, cur_y[train_inds[sample_inds_training]]))
    print(f"shape:cur={cur_x.shape},cur_subsamp={len(sample_inds_training)}, full={len(train_inds)}, all_train_x_orig={all_train_x_orig.shape},type={type(cur_x)}")

minmax_scaler = MinMaxScaler()
minmax_scaler.fit(all_train_x_orig)

train_set_x_norm = minmax_scaler.transform(data_x_clean_orig)
all_train_x_norm = minmax_scaler.transform(all_train_x_orig)

X_train_clean, X_test_clean, y_train_clean, y_test_clean, train_inds, test_inds, train_fnames, test_fnames = train_test_split \
    (train_set_x_norm, data_y_clean_orig, np.arange(train_set_x_norm.shape[0]), data_clean_fnames, test_size=0.25, random_state=1)
print(f"Type: X_train_clean={type(X_train_clean)}, y_train_clean={type(y_train_clean)}")
print(f"Shapes: X_train_clean={X_train_clean.shape}, y_train_clean={y_train_clean.shape}, X_test_clean={X_test_clean.shape}, y_test_clean={y_test_clean.shape}")

unq_vals, unq_counts = np.unique(y_train_clean, return_counts=True)
print(dict(zip(unq_vals,unq_counts)))
# Out:
# [0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ]
# SNR=-20.0 dB and weight = 0.125
# shape:cur=(1605, 67),cur_subsamp=150, full=1203, all_train_x_orig=(1353, 67),type=<class 'numpy.ndarray'>
# SNR=-15.0 dB and weight = 0.25
# shape:cur=(1605, 67),cur_subsamp=300, full=1203, all_train_x_orig=(1653, 67),type=<class 'numpy.ndarray'>
# SNR=-10.0 dB and weight = 0.375
# shape:cur=(1605, 67),cur_subsamp=451, full=1203, all_train_x_orig=(2104, 67),type=<class 'numpy.ndarray'>
# SNR=-5.0 dB and weight = 0.5
# shape:cur=(1605, 67),cur_subsamp=601, full=1203, all_train_x_orig=(2705, 67),type=<class 'numpy.ndarray'>
# SNR=0.0 dB and weight = 0.625
# shape:cur=(1605, 67),cur_subsamp=751, full=1203, all_train_x_orig=(3456, 67),type=<class 'numpy.ndarray'>
# SNR=5.0 dB and weight = 0.75
# shape:cur=(1605, 67),cur_subsamp=902, full=1203, all_train_x_orig=(4358, 67),type=<class 'numpy.ndarray'>
# SNR=10.0 dB and weight = 0.875
# shape:cur=(1605, 67),cur_subsamp=1052, full=1203, all_train_x_orig=(5410, 67),type=<class 'numpy.ndarray'>
# Type: X_train_clean=<class 'numpy.ndarray'>, y_train_clean=<class 'numpy.ndarray'>
# Shapes: X_train_clean=(1203, 67), y_train_clean=(1203,), X_test_clean=(402, 67), y_test_clean=(402,)
# {0: 327, 1: 191, 2: 285, 3: 328, 4: 72}

# %% [markdown]
# ## Model #1: An SVM model (rbf kernels seem to work the best)

# %%
svm_model = svm.SVC(kernel='rbf').fit(X_train_clean, y_train_clean)
y_train_pred = svm_model.predict(X_train_clean)
y_test_pred = svm_model.predict(X_test_clean)

print(f"Unique values in y_test_pred={np.unique(y_test_pred)}")
print(f"Unique values in y_train_clean={np.unique(y_train_clean)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_clean==y_train_pred)/len(y_train_pred)}\n Testing accuracy={np.sum(y_test_clean==y_test_pred)/len(y_test_pred)}\n")
# Out:
# Unique values in y_test_pred=[0 1 2 3 4]
# Unique values in y_train_clean=[0 1 2 3 4]
# Training accuracy=0.9650872817955112
#  Testing accuracy=0.9626865671641791

# %% [markdown]
# ## Model #2. Train an MLP

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPclean = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPclean.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

# Fit the model 
MLPclean.fit(
    X_train_clean,y_train_clean,
    epochs=200
)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 2s 2ms/step - loss: 0.8070
# Epoch 2/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3417
# Epoch 3/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2633
# Epoch 4/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2145
# Epoch 5/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1920
# Epoch 6/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1820
# Epoch 7/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1634
# Epoch 8/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1716
# Epoch 9/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1588
# Epoch 10/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1521
# Epoch 11/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1510
# Epoch 12/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1525
# Epoch 13/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1335
# Epoch 14/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1305
# Epoch 15/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1403
# Epoch 16/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1299
# Epoch 17/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1193
# Epoch 18/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1289
# Epoch 19/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1244
# Epoch 20/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1150
# Epoch 21/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1182
# Epoch 22/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1236
# Epoch 23/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1164
# Epoch 24/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1128
# Epoch 25/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1118
# Epoch 26/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1118
# Epoch 27/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1099
# Epoch 28/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1097
# Epoch 29/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1056
# Epoch 30/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1058
# Epoch 31/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1094
# Epoch 32/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1138
# Epoch 33/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1059
# Epoch 34/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0997
# Epoch 35/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1029
# Epoch 36/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1002
# Epoch 37/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0969
# Epoch 38/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0966
# Epoch 39/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0946
# Epoch 40/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0951
# Epoch 41/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0971
# Epoch 42/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0941
# Epoch 43/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0963
# Epoch 44/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0964
# Epoch 45/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0932
# Epoch 46/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0949
# Epoch 47/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0982
# Epoch 48/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0959
# Epoch 49/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0903
# Epoch 50/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0924
# Epoch 51/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0930
# Epoch 52/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0887
# Epoch 53/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0996
# Epoch 54/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0887
# Epoch 55/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0979
# Epoch 56/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0969
# Epoch 57/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0990
# Epoch 58/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0953
# Epoch 59/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0879
# Epoch 60/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 61/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0891
# Epoch 62/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0918
# Epoch 63/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0891
# Epoch 64/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 65/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0870
# Epoch 66/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 67/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 68/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0810
# Epoch 69/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 70/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0858
# Epoch 71/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 72/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0819
# Epoch 73/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 74/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0741
# Epoch 75/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0815
# Epoch 76/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0787
# Epoch 77/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0836
# Epoch 78/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0772
# Epoch 79/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0803
# Epoch 80/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0826
# Epoch 81/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0841
# Epoch 82/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 83/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 84/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 85/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0750
# Epoch 86/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 87/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0733
# Epoch 88/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0771
# Epoch 89/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 90/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 91/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 92/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0845
# Epoch 93/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0779
# Epoch 94/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0796
# Epoch 95/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0757
# Epoch 96/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0784
# Epoch 97/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 98/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0733
# Epoch 99/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 100/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0704
# Epoch 101/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0806
# Epoch 102/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0730
# Epoch 103/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0754
# Epoch 104/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0836
# Epoch 105/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 106/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0713
# Epoch 107/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 108/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0744
# Epoch 109/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0757
# Epoch 110/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0750
# Epoch 111/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0733
# Epoch 112/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0671
# Epoch 113/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 114/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0651
# Epoch 115/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 116/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0717
# Epoch 117/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0651
# Epoch 118/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0717
# Epoch 119/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 120/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0652
# Epoch 121/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0635
# Epoch 122/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0672
# Epoch 123/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0630
# Epoch 124/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 125/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 126/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 127/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 128/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 129/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 130/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0680
# Epoch 131/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0603
# Epoch 132/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0579
# Epoch 133/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0611
# Epoch 134/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 135/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 136/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0817
# Epoch 137/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0705
# Epoch 138/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0721
# Epoch 139/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0680
# Epoch 140/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0638
# Epoch 141/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0655
# Epoch 142/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0641
# Epoch 143/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 144/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 145/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0616
# Epoch 146/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0576
# Epoch 147/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0620
# Epoch 148/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0633
# Epoch 149/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0674
# Epoch 150/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0740
# Epoch 151/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 152/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 153/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 154/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0576
# Epoch 155/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0566
# Epoch 156/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0604
# Epoch 157/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 158/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0584
# Epoch 159/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0633
# Epoch 160/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 161/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0566
# Epoch 162/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 163/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0593
# Epoch 164/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 165/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 166/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0576
# Epoch 167/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 168/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 169/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0562
# Epoch 170/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 171/200
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0586
# Epoch 172/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0731
# Epoch 173/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0590
# Epoch 174/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0654
# Epoch 175/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0560
# Epoch 176/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0612
# Epoch 177/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0645
# Epoch 178/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0536
# Epoch 179/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0554
# Epoch 180/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0554
# Epoch 181/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 182/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 183/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 184/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0503
# Epoch 185/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 186/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 187/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0572
# Epoch 188/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0584
# Epoch 189/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0638
# Epoch 190/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 191/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 192/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0649
# Epoch 193/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 194/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0582
# Epoch 195/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0514
# Epoch 196/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 197/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 198/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 199/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0514
# Epoch 200/200
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0598

# %% [markdown]
# ## Test MLP accuracy for training and testing

# %%
y_train_pred_NN = np.argmax(MLPclean.predict(X_train_clean), axis=1)
y_test_pred_NN = np.argmax(MLPclean.predict(X_test_clean), axis=1)

print(f"Unique values in y_train_clean={np.unique(y_train_pred_NN)}")
print(f"Unique values in y_test_pred={np.unique(y_test_pred_NN)}")

fig, ax = plt.subplots(2,1,figsize=(4,4))
ax[0].plot(y_train_clean)
ax[1].plot(y_train_clean-y_train_pred_NN, color = "orangered")
ax[1].set_xlabel("Call numbers")

print(f"Training accuracy={np.sum(y_train_clean==y_train_pred_NN)/len(y_train_clean)}\n Testing accuracy={np.sum(y_test_clean==y_test_pred_NN)/len(y_test_clean)}\n")
# Out:
# 38/38 [==============================] - 0s 838us/step
# 13/13 [==============================] - 0s 833us/step
# Unique values in y_train_clean=[0 1 2 3 4]
# Unique values in y_test_pred=[0 1 2 3 4]
# Training accuracy=0.9842061512884456
#  Testing accuracy=0.9800995024875622

# %% [markdown]
# ## Model #3. MLP cleaned on noisy calls

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results

# Define the model 
MLPnoisy = Sequential(
    [
        Dense(10, activation = 'relu',   name = "L1"),
        Dense(5, activation = 'linear', name = "L2")
    ]
)

# Compile the model 
MLPnoisy.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
    metrics=['accuracy'],
)

# Fit the model 
MLPnoisy.fit(
    all_train_x_norm, all_train_y_orig,
    epochs=50
)
# Out:
# Epoch 1/50
# 170/170 [==============================] - 1s 2ms/step - loss: 0.5850 - accuracy: 0.7911
# Epoch 2/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.3031 - accuracy: 0.8917
# Epoch 3/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2199 - accuracy: 0.9506
# Epoch 4/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9606
# Epoch 5/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9649
# Epoch 6/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1332 - accuracy: 0.9651
# Epoch 7/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1213 - accuracy: 0.9680
# Epoch 8/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9684
# Epoch 9/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9725
# Epoch 10/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9717
# Epoch 11/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9713
# Epoch 12/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9693
# Epoch 13/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9719
# Epoch 14/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9734
# Epoch 15/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9756
# Epoch 16/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9739
# Epoch 17/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9736
# Epoch 18/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9743
# Epoch 19/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.9769
# Epoch 20/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0956 - accuracy: 0.9736
# Epoch 21/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9734
# Epoch 22/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0920 - accuracy: 0.9763
# Epoch 23/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9758
# Epoch 24/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9773
# Epoch 25/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9760
# Epoch 26/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9758
# Epoch 27/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9743
# Epoch 28/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9760
# Epoch 29/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9752
# Epoch 30/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9741
# Epoch 31/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9756
# Epoch 32/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9774
# Epoch 33/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.9762
# Epoch 34/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0875 - accuracy: 0.9769
# Epoch 35/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9776
# Epoch 36/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9762
# Epoch 37/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9776
# Epoch 38/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.9763
# Epoch 39/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 0.9758
# Epoch 40/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9797
# Epoch 41/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9786
# Epoch 42/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9763
# Epoch 43/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9754
# Epoch 44/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9795
# Epoch 45/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9791
# Epoch 46/50
# 170/170 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9773
# Epoch 47/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9795
# Epoch 48/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9795
# Epoch 49/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.9799
# Epoch 50/50
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9784

# %% [markdown]
# ## Test in different SNRs

# %%
def test_MLP_snr(MLPmodel, minmax_scaler, snr_value, test_inds_clean, test_fnames_clean):
    root_out_dir= 'D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/PyData/'
    if np.isinf(snr_value):
        out_psd_data_file = root_out_dir + 'PSD_data_clean.h5'
    else:
        out_psd_data_file = root_out_dir + 'PSD_data_SNR' + snr_value.astype('int').astype('str') + '.h5'
    cur_snr_dataset = h5py.File(out_psd_data_file, "r")
    print(cur_snr_dataset)
    data_x_orig = np.array(cur_snr_dataset["data_psd_x"][:]) # your train set features
    data_y_orig = np.ravel(np.array(cur_snr_dataset["data_label_y"][:])) # your train set labels
    data_fnames = np.ravel(np.array(cur_snr_dataset["data_filename"][:])) # your train set labels
    data_x_norm = minmax_scaler.transform(data_x_orig)

    X_test = data_x_norm[test_inds]
    y_test = data_y_orig[test_inds]
    fName_test= data_fnames[test_inds]
    
    rand_int = random.randint(0, len(test_fnames_clean))
    clean_name = test_fnames_clean[rand_int].decode("utf-8")
    noisy_name= fName_test[rand_int].decode("utf-8")

    print(f"fnumber={rand_int} |-| clean={clean_name}|noisy={noisy_name}")
    clean_name= clean_name[clean_name.rfind('/')+1:-3]
    noisy_name= noisy_name[noisy_name.rfind('/')+1:-3]
    if clean_name!=noisy_name:
        print("Should be same")
    y_test_pred_NN = np.argmax(MLPmodel.predict(X_test), axis=1)
    # accuracy = np.sum(y_test==y_test_pred_NN)/len(y_test_clean)
    # auc = skmetric.roc_auc_score(y_test, y_test_pred_NN)
    accuracy = skmetric.accuracy_score(y_test, y_test_pred_NN)
    print(f"[SNR={snr_value} dB] Accuracy={accuracy}\n")
    
    return accuracy

test_accuracy_cleanMLP = np.zeros(all_snrs.shape)
test_accuracy_noisyMLP = np.zeros(all_snrs.shape)
# test_auc_cleanMLP = np.zeros(all_snrs.shape)
# test_auc_noisyMLP = np.zeros(all_snrs.shape)

for snr_value,iter in zip(all_snrs,range(len(all_snrs))):
    test_accuracy_cleanMLP[iter]= test_MLP_snr(MLPclean, minmax_scaler, snr_value, test_inds, test_fnames)
    test_accuracy_noisyMLP[iter]= test_MLP_snr(MLPnoisy, minmax_scaler, snr_value, test_inds, test_fnames)
    
    # print(f"SNR={snr_value} dB | Accuracy={test_accuracy[iter]}")
# Out:
# <HDF5 file "PSD_data_SNR-20.h5" (mode r)>
# fnumber=264 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Wheek/psd_Wheek_2_Mar_20_2022_55452652_ms_23695_24696.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-20_white/Wheek/psd_Wheek_2_Mar_20_2022_55452652_ms_23695_24696.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-20.0 dB] Accuracy=0.0
#
# <HDF5 file "PSD_data_SNR-20.h5" (mode r)>
# fnumber=197 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_52234XXX_ms_30121_30717.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-20_white/Whine/psd_Whine_2_Mar_16_2022_52234XXX_ms_30121_30717.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-20.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR-15.h5" (mode r)>
# fnumber=344 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Rumble/psd_Rumble_3_Feb_07_2022_52190342_ms_20429_22083.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-15_white/Rumble/psd_Rumble_3_Feb_07_2022_52190342_ms_20429_22083.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-15.0 dB] Accuracy=0.0
#
# <HDF5 file "PSD_data_SNR-15.h5" (mode r)>
# fnumber=265 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_15_2022_48667041_ms_27404_28478.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-15_white/Whine/psd_Whine_2_Mar_15_2022_48667041_ms_27404_28478.mat
# 13/13 [==============================] - 0s 2ms/step
# [SNR=-15.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR-10.h5" (mode r)>
# fnumber=301 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Wheek/psd_Wheek_2_Mar_20_2022_57264788_ms_103157_104074.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-10_white/Wheek/psd_Wheek_2_Mar_20_2022_57264788_ms_103157_104074.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-10.0 dB] Accuracy=0.0
#
# <HDF5 file "PSD_data_SNR-10.h5" (mode r)>
# fnumber=376 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_54372XXX_ms_8414_9830.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-10_white/Whine/psd_Whine_2_Mar_16_2022_54372XXX_ms_8414_9830.mat
# 13/13 [==============================] - 0s 2ms/step
# [SNR=-10.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR-5.h5" (mode r)>
# fnumber=211 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Wheek/psd_Wheek_2_Mar_19_2022_55561724_ms_142379_143247.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-5_white/Wheek/psd_Wheek_2_Mar_19_2022_55561724_ms_142379_143247.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-5.0 dB] Accuracy=0.0024875621890547263
#
# <HDF5 file "PSD_data_SNR-5.h5" (mode r)>
# fnumber=4 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Rumble/psd_Rumble_2_Mar_16_2022_54043XXX_ms_6038_7042.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR-5_white/Rumble/psd_Rumble_2_Mar_16_2022_54043XXX_ms_6038_7042.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=-5.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR0.h5" (mode r)>
# fnumber=122 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Wheek/psd_Wheek_2_Mar_19_2022_53914084_ms_56400_57644.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR0_white/Wheek/psd_Wheek_2_Mar_19_2022_53914084_ms_56400_57644.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=0.0 dB] Accuracy=0.17661691542288557
#
# <HDF5 file "PSD_data_SNR0.h5" (mode r)>
# fnumber=243 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_53057XXX_ms_115383_116034.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR0_white/Whine/psd_Whine_2_Mar_16_2022_53057XXX_ms_115383_116034.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=0.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR5.h5" (mode r)>
# fnumber=139 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Chut/psd_Chut_2_Mar_16_2022_50426XXX_ms_45125_46046.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR5_white/Chut/psd_Chut_2_Mar_16_2022_50426XXX_ms_45125_46046.mat
# 13/13 [==============================] - 0s 917us/step
# [SNR=5.0 dB] Accuracy=0.05223880597014925
#
# <HDF5 file "PSD_data_SNR5.h5" (mode r)>
# fnumber=395 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Wheek/psd_Wheek_2_Mar_19_2022_52925459_ms_123190_124089.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR5_white/Wheek/psd_Wheek_2_Mar_19_2022_52925459_ms_123190_124089.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=5.0 dB] Accuracy=1.0
#
# <HDF5 file "PSD_data_SNR10.h5" (mode r)>
# fnumber=56 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_53550XXX_ms_115902_117770.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR10_white/Whine/psd_Whine_2_Mar_16_2022_53550XXX_ms_115902_117770.mat
# 13/13 [==============================] - 0s 1000us/step
# [SNR=10.0 dB] Accuracy=0.04477611940298507
#
# <HDF5 file "PSD_data_SNR10.h5" (mode r)>
# fnumber=228 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_15_2022_48502469_ms_28680_29841.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_SNR10_white/Whine/psd_Whine_2_Mar_15_2022_48502469_ms_28680_29841.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=10.0 dB] Accuracy=0.9950248756218906
#
# <HDF5 file "PSD_data_clean.h5" (mode r)>
# fnumber=377 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_50262XXX_ms_112076_113137.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/Whine/psd_Whine_2_Mar_16_2022_50262XXX_ms_112076_113137.mat
# 13/13 [==============================] - 0s 917us/step
# [SNR=inf dB] Accuracy=0.9800995024875622
#
# <HDF5 file "PSD_data_clean.h5" (mode r)>
# fnumber=316 |-| clean=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/HighWhistle/psd_HighWhistle_3_Mar_16_2022_48618XXX_ms_59261_60637.mat|noisy=D:/Dropbox/Python/MLmodels/Datasets/psd_gp_vIHC_mat/level65_dBspl_clean/HighWhistle/psd_HighWhistle_3_Mar_16_2022_48618XXX_ms_59261_60637.mat
# 13/13 [==============================] - 0s 1ms/step
# [SNR=inf dB] Accuracy=0.8805970149253731

# %% [markdown]
# ## Plot results

# %%
plot_snr= copy.deepcopy(all_snrs)
plot_snr[np.isinf(plot_snr)] = 15
plt.plot(plot_snr, test_accuracy_cleanMLP, label="Clean-trained")
plt.plot(plot_snr, test_accuracy_noisyMLP, label="Noise-trained")
plt.xlabel("SNR (dB)")
plt.ylabel("Accuracy")
plt.title("Only carrier frequency (place)")
plt.legend()

# %%
out_PSDvIHC_classify_file = root_data_dir + 'PSDvIHC_classify_out'
np.savez(out_PSDvIHC_classify_file + '.npz', all_snrs=all_snrs, test_accuracy_noisyMLP=test_accuracy_noisyMLP, test_accuracy_cleanMLP=test_accuracy_cleanMLP)
mat_dict= {"all_snrs":all_snrs, "test_accuracy_noisyMLP":test_accuracy_noisyMLP, "test_accuracy_cleanMLP":test_accuracy_cleanMLP}
savemat(out_PSDvIHC_classify_file + '.mat', mat_dict)
